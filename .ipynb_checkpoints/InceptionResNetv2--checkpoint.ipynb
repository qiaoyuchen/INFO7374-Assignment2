# %%
import time
#import myutils
import numpy as np
import tensorflow as tf
from keras.layers import Input, Dense, AveragePooling2D, GlobalAveragePooling2D
from keras import backend as K
from keras.models import Model
from keras.applications.inception_resnet_v2 import InceptionResNetV2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load CIFAR10 data
# Here we use [keras.datasets](https://keras.io/datasets/) which is pretty similar to our <tt>myutils.load_CIFAR10_dataset()</tt> procedure.

# %%
n_classes = 10
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

n_training = X_train.shape[0]
n_testing = X_test.shape[0]

y_train = y_train.flatten()
y_test  = y_test.flatten()

print( X_train.shape, y_train.shape,  X_test.shape, y_test.shape )

from matplotlib import pyplot as plt
plt.imshow( X_train[0]  )
plt.show()
# Out:
# (50000, 32, 32, 3) (50000,) (10000, 32, 32, 3) (10000,)

# %% [markdown]
# # Create model

# %%
from keras.models import Model
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.resnet50     import ResNet50
from keras.applications.vgg16        import VGG16
from keras.applications.vgg19        import VGG19

network_names = [ 'incv2' ]

print("Available networks = ", network_names)
cnnid = 0; # int( input("Please choose the CNN network [0-{n}]: ".format(n=len(network_names)-1)) )

selected_network = network_names[cnnid]
print("Selected network: ", selected_network)

input_shape = {
    'incv2'   : (224,224,3)
}[selected_network]

def create_model_incv2():
    tf_input = Input(shape=input_shape)
    base_model = InceptionResNetV2(input_tensor=tf_input, weights='imagenet', include_top=False)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(n_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return base_model, model

create_model = {
    'incv2'    : create_model_incv2
}[selected_network]
# Out:
# Available networks =  ['incv2']
# Selected network:  incv2

# %% [markdown]
# # Data generator for tensorflow
#
# The feature extraction can process the batches of data. It is common in feeding neural networks in tensorflow.

# %%
# tensorflow placeholder for batch of images from CIFAR10 dataset
batch_of_images_placeholder = tf.placeholder("uint8", (None, 32, 32, 3))

batch_size = 64

tf_resize_op = tf.image.resize_images(batch_of_images_placeholder, (224,224), method=0)

# %%
print( X_train.shape, y_train.shape,  X_test.shape, y_test.shape )
# Out:
# (50000, 32, 32, 3) (50000,) (10000, 32, 32, 3) (10000,)

# %%
# data generator for tensorflow session
from keras.applications.inception_resnet_v2 import preprocess_input as incv2_preprocess_input

preprocess_input =  incv2_preprocess_input

def data_generator(sess,data,labels):
    def generator():
        start = 0
        end = start + batch_size
        n = data.shape[0]
        while True:
            batch_of_images_resized = sess.run(tf_resize_op, {batch_of_images_placeholder: data[start:end]})
            batch_of_images__preprocessed = preprocess_input(batch_of_images_resized)
            batch_of_labels = labels[start:end]
            
            start += batch_size
            end   += batch_size
            if start >= n:
                start = 0
                end = batch_size
            yield (batch_of_images__preprocessed, batch_of_labels)
    return generator

# %% [markdown]
# # Create model

# %%
sess = tf.InteractiveSession()

# %%
K.set_session(sess)
K.set_learning_phase(1)  # 0 - test,  1 - train

# %%
base_model, model = create_model()

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)
# Out:
# 0 input_2
# 1 conv2d_204
# 2 batch_normalization_204
# 3 activation_204
# 4 conv2d_205
# 5 batch_normalization_205
# 6 activation_205
# 7 conv2d_206
# 8 batch_normalization_206
# 9 activation_206
# 10 max_pooling2d_5
# 11 conv2d_207
# 12 batch_normalization_207
# 13 activation_207
# 14 conv2d_208
# 15 batch_normalization_208
# 16 activation_208
# 17 max_pooling2d_6
# 18 conv2d_212
# 19 batch_normalization_212
# 20 activation_212
# 21 conv2d_210
# 22 conv2d_213
# 23 batch_normalization_210
# 24 batch_normalization_213
# 25 activation_210
# 26 activation_213
# 27 average_pooling2d_2
# 28 conv2d_209
# 29 conv2d_211
# 30 conv2d_214
# 31 conv2d_215
# 32 batch_normalization_209
# 33 batch_normalization_211
# 34 batch_normalization_214
# 35 batch_normalization_215
# 36 activation_209
# 37 activation_211
# 38 activation_214
# 39 activation_215
# 40 mixed_5b
# 41 conv2d_219
# 42 batch_normalization_219
# 43 activation_219
# 44 conv2d_217
# 45 conv2d_220
# 46 batch_normalization_217
# 47 batch_normalization_220
# 48 activation_217
# 49 activation_220
# 50 conv2d_216
# 51 conv2d_218
# 52 conv2d_221
# 53 batch_normalization_216
# 54 batch_normalization_218
# 55 batch_normalization_221
# 56 activation_216
# 57 activation_218
# 58 activation_221
# 59 block35_1_mixed
# 60 block35_1_conv
# 61 block35_1
# 62 block35_1_ac
# 63 conv2d_225
# 64 batch_normalization_225
# 65 activation_225
# 66 conv2d_223
# 67 conv2d_226
# 68 batch_normalization_223
# 69 batch_normalization_226
# 70 activation_223
# 71 activation_226
# 72 conv2d_222
# 73 conv2d_224
# 74 conv2d_227
# 75 batch_normalization_222
# 76 batch_normalization_224
# 77 batch_normalization_227
# 78 activation_222
# 79 activation_224
# 80 activation_227
# 81 block35_2_mixed
# 82 block35_2_conv
# 83 block35_2
# 84 block35_2_ac
# 85 conv2d_231
# 86 batch_normalization_231
# 87 activation_231
# 88 conv2d_229
# 89 conv2d_232
# 90 batch_normalization_229
# 91 batch_normalization_232
# 92 activation_229
# 93 activation_232
# 94 conv2d_228
# 95 conv2d_230
# 96 conv2d_233
# 97 batch_normalization_228
# 98 batch_normalization_230
# 99 batch_normalization_233
# 100 activation_228
# 101 activation_230
# 102 activation_233
# 103 block35_3_mixed
# 104 block35_3_conv
# 105 block35_3
# 106 block35_3_ac
# 107 conv2d_237
# 108 batch_normalization_237
# 109 activation_237
# 110 conv2d_235
# 111 conv2d_238
# 112 batch_normalization_235
# 113 batch_normalization_238
# 114 activation_235
# 115 activation_238
# 116 conv2d_234
# 117 conv2d_236
# 118 conv2d_239
# 119 batch_normalization_234
# 120 batch_normalization_236
# 121 batch_normalization_239
# 122 activation_234
# 123 activation_236
# 124 activation_239
# 125 block35_4_mixed
# 126 block35_4_conv
# 127 block35_4
# 128 block35_4_ac
# 129 conv2d_243
# 130 batch_normalization_243
# 131 activation_243
# 132 conv2d_241
# 133 conv2d_244
# 134 batch_normalization_241
# 135 batch_normalization_244
# 136 activation_241
# 137 activation_244
# 138 conv2d_240
# 139 conv2d_242
# 140 conv2d_245
# 141 batch_normalization_240
# 142 batch_normalization_242
# 143 batch_normalization_245
# 144 activation_240
# 145 activation_242
# 146 activation_245
# 147 block35_5_mixed
# 148 block35_5_conv
# 149 block35_5
# 150 block35_5_ac
# 151 conv2d_249
# 152 batch_normalization_249
# 153 activation_249
# 154 conv2d_247
# 155 conv2d_250
# 156 batch_normalization_247
# 157 batch_normalization_250
# 158 activation_247
# 159 activation_250
# 160 conv2d_246
# 161 conv2d_248
# 162 conv2d_251
# 163 batch_normalization_246
# 164 batch_normalization_248
# 165 batch_normalization_251
# 166 activation_246
# 167 activation_248
# 168 activation_251
# 169 block35_6_mixed
# 170 block35_6_conv
# 171 block35_6
# 172 block35_6_ac
# 173 conv2d_255
# 174 batch_normalization_255
# 175 activation_255
# 176 conv2d_253
# 177 conv2d_256
# 178 batch_normalization_253
# 179 batch_normalization_256
# 180 activation_253
# 181 activation_256
# 182 conv2d_252
# 183 conv2d_254
# 184 conv2d_257
# 185 batch_normalization_252
# 186 batch_normalization_254
# 187 batch_normalization_257
# 188 activation_252
# 189 activation_254
# 190 activation_257
# 191 block35_7_mixed
# 192 block35_7_conv
# 193 block35_7
# 194 block35_7_ac
# 195 conv2d_261
# 196 batch_normalization_261
# 197 activation_261
# 198 conv2d_259
# 199 conv2d_262
# 200 batch_normalization_259
# 201 batch_normalization_262
# 202 activation_259
# 203 activation_262
# 204 conv2d_258
# 205 conv2d_260
# 206 conv2d_263
# 207 batch_normalization_258
# 208 batch_normalization_260
# 209 batch_normalization_263
# 210 activation_258
# 211 activation_260
# 212 activation_263
# 213 block35_8_mixed
# 214 block35_8_conv
# 215 block35_8
# 216 block35_8_ac
# 217 conv2d_267
# 218 batch_normalization_267
# 219 activation_267
# 220 conv2d_265
# 221 conv2d_268
# 222 batch_normalization_265
# 223 batch_normalization_268
# 224 activation_265
# 225 activation_268
# 226 conv2d_264
# 227 conv2d_266
# 228 conv2d_269
# 229 batch_normalization_264
# 230 batch_normalization_266
# 231 batch_normalization_269
# 232 activation_264
# 233 activation_266
# 234 activation_269
# 235 block35_9_mixed
# 236 block35_9_conv
# 237 block35_9
# 238 block35_9_ac
# 239 conv2d_273
# 240 batch_normalization_273
# 241 activation_273
# 242 conv2d_271
# 243 conv2d_274
# 244 batch_normalization_271
# 245 batch_normalization_274
# 246 activation_271
# 247 activation_274
# 248 conv2d_270
# 249 conv2d_272
# 250 conv2d_275
# 251 batch_normalization_270
# 252 batch_normalization_272
# 253 batch_normalization_275
# 254 activation_270
# 255 activation_272
# 256 activation_275
# 257 block35_10_mixed
# 258 block35_10_conv
# 259 block35_10
# 260 block35_10_ac
# 261 conv2d_277
# 262 batch_normalization_277
# 263 activation_277
# 264 conv2d_278
# 265 batch_normalization_278
# 266 activation_278
# 267 conv2d_276
# 268 conv2d_279
# 269 batch_normalization_276
# 270 batch_normalization_279
# 271 activation_276
# 272 activation_279
# 273 max_pooling2d_7
# 274 mixed_6a
# 275 conv2d_281
# 276 batch_normalization_281
# 277 activation_281
# 278 conv2d_282
# 279 batch_normalization_282
# 280 activation_282
# 281 conv2d_280
# 282 conv2d_283
# 283 batch_normalization_280
# 284 batch_normalization_283
# 285 activation_280
# 286 activation_283
# 287 block17_1_mixed
# 288 block17_1_conv
# 289 block17_1
# 290 block17_1_ac
# 291 conv2d_285
# 292 batch_normalization_285
# 293 activation_285
# 294 conv2d_286
# 295 batch_normalization_286
# 296 activation_286
# 297 conv2d_284
# 298 conv2d_287
# 299 batch_normalization_284
# 300 batch_normalization_287
# 301 activation_284
# 302 activation_287
# 303 block17_2_mixed
# 304 block17_2_conv
# 305 block17_2
# 306 block17_2_ac
# 307 conv2d_289
# 308 batch_normalization_289
# 309 activation_289
# 310 conv2d_290
# 311 batch_normalization_290
# 312 activation_290
# 313 conv2d_288
# 314 conv2d_291
# 315 batch_normalization_288
# 316 batch_normalization_291
# 317 activation_288
# 318 activation_291
# 319 block17_3_mixed
# 320 block17_3_conv
# 321 block17_3
# 322 block17_3_ac
# 323 conv2d_293
# 324 batch_normalization_293
# 325 activation_293
# 326 conv2d_294
# 327 batch_normalization_294
# 328 activation_294
# 329 conv2d_292
# 330 conv2d_295
# 331 batch_normalization_292
# 332 batch_normalization_295
# 333 activation_292
# 334 activation_295
# 335 block17_4_mixed
# 336 block17_4_conv
# 337 block17_4
# 338 block17_4_ac
# 339 conv2d_297
# 340 batch_normalization_297
# 341 activation_297
# 342 conv2d_298
# 343 batch_normalization_298
# 344 activation_298
# 345 conv2d_296
# 346 conv2d_299
# 347 batch_normalization_296
# 348 batch_normalization_299
# 349 activation_296
# 350 activation_299
# 351 block17_5_mixed
# 352 block17_5_conv
# 353 block17_5
# 354 block17_5_ac
# 355 conv2d_301
# 356 batch_normalization_301
# 357 activation_301
# 358 conv2d_302
# 359 batch_normalization_302
# 360 activation_302
# 361 conv2d_300
# 362 conv2d_303
# 363 batch_normalization_300
# 364 batch_normalization_303
# 365 activation_300
# 366 activation_303
# 367 block17_6_mixed
# 368 block17_6_conv
# 369 block17_6
# 370 block17_6_ac
# 371 conv2d_305
# 372 batch_normalization_305
# 373 activation_305
# 374 conv2d_306
# 375 batch_normalization_306
# 376 activation_306
# 377 conv2d_304
# 378 conv2d_307
# 379 batch_normalization_304
# 380 batch_normalization_307
# 381 activation_304
# 382 activation_307
# 383 block17_7_mixed
# 384 block17_7_conv
# 385 block17_7
# 386 block17_7_ac
# 387 conv2d_309
# 388 batch_normalization_309
# 389 activation_309
# 390 conv2d_310
# 391 batch_normalization_310
# 392 activation_310
# 393 conv2d_308
# 394 conv2d_311
# 395 batch_normalization_308
# 396 batch_normalization_311
# 397 activation_308
# 398 activation_311
# 399 block17_8_mixed
# 400 block17_8_conv
# 401 block17_8
# 402 block17_8_ac
# 403 conv2d_313
# 404 batch_normalization_313
# 405 activation_313
# 406 conv2d_314
# 407 batch_normalization_314
# 408 activation_314
# 409 conv2d_312
# 410 conv2d_315
# 411 batch_normalization_312
# 412 batch_normalization_315
# 413 activation_312
# 414 activation_315
# 415 block17_9_mixed
# 416 block17_9_conv
# 417 block17_9
# 418 block17_9_ac
# 419 conv2d_317
# 420 batch_normalization_317
# 421 activation_317
# 422 conv2d_318
# 423 batch_normalization_318
# 424 activation_318
# 425 conv2d_316
# 426 conv2d_319
# 427 batch_normalization_316
# 428 batch_normalization_319
# 429 activation_316
# 430 activation_319
# 431 block17_10_mixed
# 432 block17_10_conv
# 433 block17_10
# 434 block17_10_ac
# 435 conv2d_321
# 436 batch_normalization_321
# 437 activation_321
# 438 conv2d_322
# 439 batch_normalization_322
# 440 activation_322
# 441 conv2d_320
# 442 conv2d_323
# 443 batch_normalization_320
# 444 batch_normalization_323
# 445 activation_320
# 446 activation_323
# 447 block17_11_mixed
# 448 block17_11_conv
# 449 block17_11
# 450 block17_11_ac
# 451 conv2d_325
# 452 batch_normalization_325
# 453 activation_325
# 454 conv2d_326
# 455 batch_normalization_326
# 456 activation_326
# 457 conv2d_324
# 458 conv2d_327
# 459 batch_normalization_324
# 460 batch_normalization_327
# 461 activation_324
# 462 activation_327
# 463 block17_12_mixed
# 464 block17_12_conv
# 465 block17_12
# 466 block17_12_ac
# 467 conv2d_329
# 468 batch_normalization_329
# 469 activation_329
# 470 conv2d_330
# 471 batch_normalization_330
# 472 activation_330
# 473 conv2d_328
# 474 conv2d_331
# 475 batch_normalization_328
# 476 batch_normalization_331
# 477 activation_328
# 478 activation_331
# 479 block17_13_mixed
# 480 block17_13_conv
# 481 block17_13
# 482 block17_13_ac
# 483 conv2d_333
# 484 batch_normalization_333
# 485 activation_333
# 486 conv2d_334
# 487 batch_normalization_334
# 488 activation_334
# 489 conv2d_332
# 490 conv2d_335
# 491 batch_normalization_332
# 492 batch_normalization_335
# 493 activation_332
# 494 activation_335
# 495 block17_14_mixed
# 496 block17_14_conv
# 497 block17_14
# 498 block17_14_ac
# 499 conv2d_337
# 500 batch_normalization_337
# 501 activation_337
# 502 conv2d_338
# 503 batch_normalization_338
# 504 activation_338
# 505 conv2d_336
# 506 conv2d_339
# 507 batch_normalization_336
# 508 batch_normalization_339
# 509 activation_336
# 510 activation_339
# 511 block17_15_mixed
# 512 block17_15_conv
# 513 block17_15
# 514 block17_15_ac
# 515 conv2d_341
# 516 batch_normalization_341
# 517 activation_341
# 518 conv2d_342
# 519 batch_normalization_342
# 520 activation_342
# 521 conv2d_340
# 522 conv2d_343
# 523 batch_normalization_340
# 524 batch_normalization_343
# 525 activation_340
# 526 activation_343
# 527 block17_16_mixed
# 528 block17_16_conv
# 529 block17_16
# 530 block17_16_ac
# 531 conv2d_345
# 532 batch_normalization_345
# 533 activation_345
# 534 conv2d_346
# 535 batch_normalization_346
# 536 activation_346
# 537 conv2d_344
# 538 conv2d_347
# 539 batch_normalization_344
# 540 batch_normalization_347
# 541 activation_344
# 542 activation_347
# 543 block17_17_mixed
# 544 block17_17_conv
# 545 block17_17
# 546 block17_17_ac
# 547 conv2d_349
# 548 batch_normalization_349
# 549 activation_349
# 550 conv2d_350
# 551 batch_normalization_350
# 552 activation_350
# 553 conv2d_348
# 554 conv2d_351
# 555 batch_normalization_348
# 556 batch_normalization_351
# 557 activation_348
# 558 activation_351
# 559 block17_18_mixed
# 560 block17_18_conv
# 561 block17_18
# 562 block17_18_ac
# 563 conv2d_353
# 564 batch_normalization_353
# 565 activation_353
# 566 conv2d_354
# 567 batch_normalization_354
# 568 activation_354
# 569 conv2d_352
# 570 conv2d_355
# 571 batch_normalization_352
# 572 batch_normalization_355
# 573 activation_352
# 574 activation_355
# 575 block17_19_mixed
# 576 block17_19_conv
# 577 block17_19
# 578 block17_19_ac
# 579 conv2d_357
# 580 batch_normalization_357
# 581 activation_357
# 582 conv2d_358
# 583 batch_normalization_358
# 584 activation_358
# 585 conv2d_356
# 586 conv2d_359
# 587 batch_normalization_356
# 588 batch_normalization_359
# 589 activation_356
# 590 activation_359
# 591 block17_20_mixed
# 592 block17_20_conv
# 593 block17_20
# 594 block17_20_ac
# 595 conv2d_364
# 596 batch_normalization_364
# 597 activation_364
# 598 conv2d_360
# 599 conv2d_362
# 600 conv2d_365
# 601 batch_normalization_360
# 602 batch_normalization_362
# 603 batch_normalization_365
# 604 activation_360
# 605 activation_362
# 606 activation_365
# 607 conv2d_361
# 608 conv2d_363
# 609 conv2d_366
# 610 batch_normalization_361
# 611 batch_normalization_363
# 612 batch_normalization_366
# 613 activation_361
# 614 activation_363
# 615 activation_366
# 616 max_pooling2d_8
# 617 mixed_7a
# 618 conv2d_368
# 619 batch_normalization_368
# 620 activation_368
# 621 conv2d_369
# 622 batch_normalization_369
# 623 activation_369
# 624 conv2d_367
# 625 conv2d_370
# 626 batch_normalization_367
# 627 batch_normalization_370
# 628 activation_367
# 629 activation_370
# 630 block8_1_mixed
# 631 block8_1_conv
# 632 block8_1
# 633 block8_1_ac
# 634 conv2d_372
# 635 batch_normalization_372
# 636 activation_372
# 637 conv2d_373
# 638 batch_normalization_373
# 639 activation_373
# 640 conv2d_371
# 641 conv2d_374
# 642 batch_normalization_371
# 643 batch_normalization_374
# 644 activation_371
# 645 activation_374
# 646 block8_2_mixed
# 647 block8_2_conv
# 648 block8_2
# 649 block8_2_ac
# 650 conv2d_376
# 651 batch_normalization_376
# 652 activation_376
# 653 conv2d_377
# 654 batch_normalization_377
# 655 activation_377
# 656 conv2d_375
# 657 conv2d_378
# 658 batch_normalization_375
# 659 batch_normalization_378
# 660 activation_375
# 661 activation_378
# 662 block8_3_mixed
# 663 block8_3_conv
# 664 block8_3
# 665 block8_3_ac
# 666 conv2d_380
# 667 batch_normalization_380
# 668 activation_380
# 669 conv2d_381
# 670 batch_normalization_381
# 671 activation_381
# 672 conv2d_379
# 673 conv2d_382
# 674 batch_normalization_379
# 675 batch_normalization_382
# 676 activation_379
# 677 activation_382
# 678 block8_4_mixed
# 679 block8_4_conv
# 680 block8_4
# 681 block8_4_ac
# 682 conv2d_384
# 683 batch_normalization_384
# 684 activation_384
# 685 conv2d_385
# 686 batch_normalization_385
# 687 activation_385
# 688 conv2d_383
# 689 conv2d_386
# 690 batch_normalization_383
# 691 batch_normalization_386
# 692 activation_383
# 693 activation_386
# 694 block8_5_mixed
# 695 block8_5_conv
# 696 block8_5
# 697 block8_5_ac
# 698 conv2d_388
# 699 batch_normalization_388
# 700 activation_388
# 701 conv2d_389
# 702 batch_normalization_389
# 703 activation_389
# 704 conv2d_387
# 705 conv2d_390
# 706 batch_normalization_387
# 707 batch_normalization_390
# 708 activation_387
# 709 activation_390
# 710 block8_6_mixed
# 711 block8_6_conv
# 712 block8_6
# 713 block8_6_ac
# 714 conv2d_392
# 715 batch_normalization_392
# 716 activation_392
# 717 conv2d_393
# 718 batch_normalization_393
# 719 activation_393
# 720 conv2d_391
# 721 conv2d_394
# 722 batch_normalization_391
# 723 batch_normalization_394
# 724 activation_391
# 725 activation_394
# 726 block8_7_mixed
# 727 block8_7_conv
# 728 block8_7
# 729 block8_7_ac
# 730 conv2d_396
# 731 batch_normalization_396
# 732 activation_396
# 733 conv2d_397
# 734 batch_normalization_397
# 735 activation_397
# 736 conv2d_395
# 737 conv2d_398
# 738 batch_normalization_395
# 739 batch_normalization_398
# 740 activation_395
# 741 activation_398
# 742 block8_8_mixed
# 743 block8_8_conv
# 744 block8_8
# 745 block8_8_ac
# 746 conv2d_400
# 747 batch_normalization_400
# 748 activation_400
# 749 conv2d_401
# 750 batch_normalization_401
# 751 activation_401
# 752 conv2d_399
# 753 conv2d_402
# 754 batch_normalization_399
# 755 batch_normalization_402
# 756 activation_399
# 757 activation_402
# 758 block8_9_mixed
# 759 block8_9_conv
# 760 block8_9
# 761 block8_9_ac
# 762 conv2d_404
# 763 batch_normalization_404
# 764 activation_404
# 765 conv2d_405
# 766 batch_normalization_405
# 767 activation_405
# 768 conv2d_403
# 769 conv2d_406
# 770 batch_normalization_403
# 771 batch_normalization_406
# 772 activation_403
# 773 activation_406
# 774 block8_10_mixed
# 775 block8_10_conv
# 776 block8_10
# 777 conv_7b
# 778 conv_7b_bn
# 779 conv_7b_ac

# %%
for layer in base_model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001EA745FAD30> False
# <keras.layers.convolutional.Conv2D object at 0x000001EA745799B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA74433CC0> True
# <keras.layers.core.Activation object at 0x000001EA74538D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA74408D30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA74387B70> True
# <keras.layers.core.Activation object at 0x000001EA73C95470> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA740AB9B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA73B8A710> True
# <keras.layers.core.Activation object at 0x000001EA00A46E10> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001EA73C4CB70> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA758E6E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA00C200F0> True
# <keras.layers.core.Activation object at 0x000001EA00C20240> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA062BE8D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA062DD2E8> True
# <keras.layers.core.Activation object at 0x000001EA062FCF98> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001EA06A4FAC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA06CFAB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA06D2FFD0> True
# <keras.layers.core.Activation object at 0x000001EA06C9DC18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA06B54588> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA08ECEDD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA06B78748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA08EF23C8> True
# <keras.layers.core.Activation object at 0x000001EA06B289B0> True
# <keras.layers.core.Activation object at 0x000001EA08F1B5C0> True
# <keras.layers.pooling.AveragePooling2D object at 0x000001EA09079BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA069FB828> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA06BC5240> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA08FAA6D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA0901F4A8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA06AC8668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA06C4F320> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA08FD2898> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA09115EB8> True
# <keras.layers.core.Activation object at 0x000001EA06AC8D68> True
# <keras.layers.core.Activation object at 0x000001EA06C6EFD0> True
# <keras.layers.core.Activation object at 0x000001EA08FF6E48> True
# <keras.layers.core.Activation object at 0x000001EA090AA208> True
# <keras.layers.merge.Concatenate object at 0x000001EA09188E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA09BACCC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA09BC4DD8> True
# <keras.layers.core.Activation object at 0x000001EA09B199B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA099C98D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA09BEEF98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA099ECA90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA09CA6710> True
# <keras.layers.core.Activation object at 0x000001EA09A0DB38> True
# <keras.layers.core.Activation object at 0x000001EA09CC8908> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA090F4B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA09A97EF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA09D4EA20> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA099379B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA09ACE128> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1260D1D0> True
# <keras.layers.core.Activation object at 0x000001EA09978EB8> True
# <keras.layers.core.Activation object at 0x000001EA09A40780> True
# <keras.layers.core.Activation object at 0x000001EA12631C50> True
# <keras.layers.merge.Concatenate object at 0x000001EA126BB5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1270ADD8> True
# <keras.layers.core.Lambda object at 0x000001EA126F1E10> True
# <keras.layers.core.Activation object at 0x000001EA12736CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1292AEF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA129E4780> True
# <keras.layers.core.Activation object at 0x000001EA1295A048> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA127EB320> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12A30278> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1280DE80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12AC1358> True
# <keras.layers.core.Activation object at 0x000001EA127EBA90> True
# <keras.layers.core.Activation object at 0x000001EA12AE2F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12736E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12857400> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12B6BB38> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA127C4F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12903D30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12BA3E10> True
# <keras.layers.core.Activation object at 0x000001EA127C4A58> True
# <keras.layers.core.Activation object at 0x000001EA12857438> True
# <keras.layers.core.Activation object at 0x000001EA12B0EC50> True
# <keras.layers.merge.Concatenate object at 0x000001EA12BEAD68> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12BEAE80> True
# <keras.layers.core.Lambda object at 0x000001EA12CC0AC8> True
# <keras.layers.core.Activation object at 0x000001EA12CC0B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12F3F9E8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12F703C8> True
# <keras.layers.core.Activation object at 0x000001EA12F91C18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12D9BC88> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1301B828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12DB4DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13053F28> True
# <keras.layers.core.Activation object at 0x000001EA12E0C358> True
# <keras.layers.core.Activation object at 0x000001EA12FC00F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12CC0710> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA12DDCF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA130980B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12D51DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA12E956D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13149470> True
# <keras.layers.core.Activation object at 0x000001EA12D79C18> True
# <keras.layers.core.Activation object at 0x000001EA12EBA8D0> True
# <keras.layers.core.Activation object at 0x000001EA13173668> True
# <keras.layers.merge.Concatenate object at 0x000001EA13200780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA131A2588> True
# <keras.layers.core.Lambda object at 0x000001EA13247FD0> True
# <keras.layers.core.Activation object at 0x000001EA132D26A0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA134CCB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA134FEFD0> True
# <keras.layers.core.Activation object at 0x000001EA1346EC18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13308E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA135D7DD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13346748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA136003C8> True
# <keras.layers.core.Activation object at 0x000001EA13328320> True
# <keras.layers.core.Activation object at 0x000001EA136295C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13247EF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13392240> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA136BC6D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13308B70> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1341F320> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA136E4898> True
# <keras.layers.core.Activation object at 0x000001EA13308908> True
# <keras.layers.core.Activation object at 0x000001EA13440FD0> True
# <keras.layers.core.Activation object at 0x000001EA13707E48> True
# <keras.layers.merge.Concatenate object at 0x000001EA13793BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA137335F8> True
# <keras.layers.core.Lambda object at 0x000001EA137C5D30> True
# <keras.layers.core.Activation object at 0x000001EA13832FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13AA4E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13AC9438> True
# <keras.layers.core.Activation object at 0x000001EA13A15080> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA138C8438> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13B231D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA138E7390> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13BB37F0> True
# <keras.layers.core.Activation object at 0x000001EA13909BE0> True
# <keras.layers.core.Activation object at 0x000001EA13BD7DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13832EB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13999FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13C5FB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA138ACF98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA139D0EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13C92048> True
# <keras.layers.core.Activation object at 0x000001EA138AC780> True
# <keras.layers.core.Activation object at 0x000001EA13935080> True
# <keras.layers.core.Activation object at 0x000001EA13D00F28> True
# <keras.layers.merge.Concatenate object at 0x000001EA13D406D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13D8DFD0> True
# <keras.layers.core.Lambda object at 0x000001EA13DBFE10> True
# <keras.layers.core.Activation object at 0x000001EA13DBF780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA150516A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1507A860> True
# <keras.layers.core.Activation object at 0x000001EA150A1A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13E73400> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA6412EE80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13E98F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA73D14F60> True
# <keras.layers.core.Activation object at 0x000001EA13E73B70> True
# <keras.layers.core.Activation object at 0x000001EA73FAAF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA13DBFCF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA14F6FCF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA73E7EDA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA13E4DBA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA14F96E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA7416E860> True
# <keras.layers.core.Activation object at 0x000001EA13E4DDA0> True
# <keras.layers.core.Activation object at 0x000001EA14FBF588> True
# <keras.layers.core.Activation object at 0x000001EA74523320> True
# <keras.layers.merge.Concatenate object at 0x000001EA742C8F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA745D06A0> True
# <keras.layers.core.Lambda object at 0x000001EA756CADA0> True
# <keras.layers.core.Activation object at 0x000001EA7570C240> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15552E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15609588> True
# <keras.layers.core.Activation object at 0x000001EA15552F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15407438> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA156571D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15424390> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA156EBA20> True
# <keras.layers.core.Activation object at 0x000001EA154D38D0> True
# <keras.layers.core.Activation object at 0x000001EA1570BB38> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA75676780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15407748> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1573C7F0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA153E8F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1550AE10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA157CFF28> True
# <keras.layers.core.Activation object at 0x000001EA153E8780> True
# <keras.layers.core.Activation object at 0x000001EA15471198> True
# <keras.layers.core.Activation object at 0x000001EA15799A90> True
# <keras.layers.merge.Concatenate object at 0x000001EA15814128> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA158145C0> True
# <keras.layers.core.Lambda object at 0x000001EA158F2BA8> True
# <keras.layers.core.Activation object at 0x000001EA158F2BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15B7DC18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15BB0240> True
# <keras.layers.core.Activation object at 0x000001EA15C5A860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA159D0E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15B1D668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA159E6400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15CA9DA0> True
# <keras.layers.core.Activation object at 0x000001EA159A9C50> True
# <keras.layers.core.Activation object at 0x000001EA15BFD080> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA158F27F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15A400B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15CD4E48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA159A91D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15ACF898> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15D8F7F0> True
# <keras.layers.core.Activation object at 0x000001EA159A9FD0> True
# <keras.layers.core.Activation object at 0x000001EA15AECE80> True
# <keras.layers.core.Activation object at 0x000001EA15DB7E10> True
# <keras.layers.merge.Concatenate object at 0x000001EA15E40B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15DDF5C0> True
# <keras.layers.core.Lambda object at 0x000001EA15EDEF60> True
# <keras.layers.core.Activation object at 0x000001EA15EDE2B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA160BE780> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16178668> True
# <keras.layers.core.Activation object at 0x000001EA160BEF98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15F72518> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA161C41D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15F903C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16257EB8> True
# <keras.layers.core.Activation object at 0x000001EA16000F98> True
# <keras.layers.core.Activation object at 0x000001EA16278BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA15EBDBE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16042B38> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16307B70> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA15F56C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16077EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16338E48> True
# <keras.layers.core.Activation object at 0x000001EA15F56748> True
# <keras.layers.core.Activation object at 0x000001EA16092F28> True
# <keras.layers.core.Activation object at 0x000001EA16355DD8> True
# <keras.layers.merge.Concatenate object at 0x000001EA16380E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16380F98> True
# <keras.layers.core.Lambda object at 0x000001EA16459C88> True
# <keras.layers.core.Activation object at 0x000001EA164E5B38> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA168BC748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16950E80> True
# <keras.layers.core.Activation object at 0x000001EA1691AF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16517DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16A23C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA165584E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16A4ADD8> True
# <keras.layers.core.Activation object at 0x000001EA165176A0> True
# <keras.layers.core.Activation object at 0x000001EA16A705F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16459CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA167D8198> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16B06710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16517908> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1686B978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16B2B8D0> True
# <keras.layers.core.Activation object at 0x000001EA16540320> True
# <keras.layers.core.Activation object at 0x000001EA16888B00> True
# <keras.layers.core.Activation object at 0x000001EA16B4BEB8> True
# <keras.layers.merge.Concatenate object at 0x000001EA16BDCC50> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16B7D6A0> True
# <keras.layers.core.Lambda object at 0x000001EA16C51C88> True
# <keras.layers.core.Activation object at 0x000001EA16C510B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16D0C5F8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16D2E080> True
# <keras.layers.core.Activation object at 0x000001EA16DD9BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16D0C908> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16E13F98> True
# <keras.layers.core.Activation object at 0x000001EA16D7A0F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16C51A90> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA16E5A828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16CE1D68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA16F0D748> True
# <keras.layers.core.Activation object at 0x000001EA16CE1828> True
# <keras.layers.core.Activation object at 0x000001EA16F31DD8> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001EA16FBAB38> True
# <keras.layers.merge.Concatenate object at 0x000001EA16F59438> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA170CD400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA170E95C0> True
# <keras.layers.core.Activation object at 0x000001EA17098D68> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17136128> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA171CAA20> True
# <keras.layers.core.Activation object at 0x000001EA171E9FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17007E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1727AB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1707B748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA172AEFD0> True
# <keras.layers.core.Activation object at 0x000001EA170362E8> True
# <keras.layers.core.Activation object at 0x000001EA17215C18> True
# <keras.layers.merge.Concatenate object at 0x000001EA172F4DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA172F4FD0> True
# <keras.layers.core.Lambda object at 0x000001EA173D3B70> True
# <keras.layers.core.Activation object at 0x000001EA173D3BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA174B0E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA174C9438> True
# <keras.layers.core.Activation object at 0x000001EA17488C88> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA175210F0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA175AC8D0> True
# <keras.layers.core.Activation object at 0x000001EA175CAEB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA173D37B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1765BC50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17488198> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17690278> True
# <keras.layers.core.Activation object at 0x000001EA17488FD0> True
# <keras.layers.core.Activation object at 0x000001EA175FD6A0> True
# <keras.layers.merge.Concatenate object at 0x000001EA17768CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA176DBC18> True
# <keras.layers.core.Lambda object at 0x000001EA177B3A20> True
# <keras.layers.core.Activation object at 0x000001EA177B3A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1786F4E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA178AEDD8> True
# <keras.layers.core.Activation object at 0x000001EA1786FE48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA178D7F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17996710> True
# <keras.layers.core.Activation object at 0x000001EA179B8978> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA177B3668> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17A40A90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17847D30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17A743C8> True
# <keras.layers.core.Activation object at 0x000001EA17847E48> True
# <keras.layers.core.Activation object at 0x000001EA17AE0FD0> True
# <keras.layers.merge.Concatenate object at 0x000001EA17B20E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17B6FD68> True
# <keras.layers.core.Lambda object at 0x000001EA17B99E10> True
# <keras.layers.core.Activation object at 0x000001EA17B99FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17C93F28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17C79EF0> True
# <keras.layers.core.Activation object at 0x000001EA17C534E0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17CBFC50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17D76588> True
# <keras.layers.core.Activation object at 0x000001EA17DA0860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17B99358> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17E32978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17C2EBE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA17E56358> True
# <keras.layers.core.Activation object at 0x000001EA17C2ED30> True
# <keras.layers.core.Activation object at 0x000001EA17E76C18> True
# <keras.layers.merge.Concatenate object at 0x000001EA17F035C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17F55E48> True
# <keras.layers.core.Lambda object at 0x000001EA17F7FD68> True
# <keras.layers.core.Activation object at 0x000001EA17F7F6D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA180393C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1805EF28> True
# <keras.layers.core.Activation object at 0x000001EA18039B38> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA18132E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1815A438> True
# <keras.layers.core.Activation object at 0x000001EA181826A0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA17F7FC50> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA182167B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA18011F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA18239978> True
# <keras.layers.core.Activation object at 0x000001EA18011A90> True
# <keras.layers.core.Activation object at 0x000001EA1825AB00> True
# <keras.layers.merge.Concatenate object at 0x000001EA1828B748> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA182EAF60> True
# <keras.layers.core.Lambda object at 0x000001EA18363B00> True
# <keras.layers.core.Activation object at 0x000001EA18363588> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1841C208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1843F240> True
# <keras.layers.core.Activation object at 0x000001EA1841C9B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA18539D68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA18515FD0> True
# <keras.layers.core.Activation object at 0x000001EA1848A3C8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA18363BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA185618D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA183F5EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA186217F0> True
# <keras.layers.core.Activation object at 0x000001EA183F5A20> True
# <keras.layers.core.Activation object at 0x000001EA18644FD0> True
# <keras.layers.merge.Concatenate object at 0x000001EA186CEBE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA18670630> True
# <keras.layers.core.Lambda object at 0x000001EA1974EF28> True
# <keras.layers.core.Activation object at 0x000001EA1974EF98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA197E44E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19802208> True
# <keras.layers.core.Activation object at 0x000001EA19871F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA198B1AC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA198E7EB8> True
# <keras.layers.core.Activation object at 0x000001EA199580B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1874EBA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1992FFD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA197C8C50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA199E46A0> True
# <keras.layers.core.Activation object at 0x000001EA197C8710> True
# <keras.layers.core.Activation object at 0x000001EA19A08908> True
# <keras.layers.merge.Concatenate object at 0x000001EA19A91A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19A34828> True
# <keras.layers.core.Lambda object at 0x000001EA19AE4E48> True
# <keras.layers.core.Activation object at 0x000001EA19AE4E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19BC8390> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19BE72E8> True
# <keras.layers.core.Activation object at 0x000001EA19C06C18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19C94828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19CCEF28> True
# <keras.layers.core.Activation object at 0x000001EA19C350F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19B10898> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19D12128> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19BA7EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19DC74E0> True
# <keras.layers.core.Activation object at 0x000001EA19BA7668> True
# <keras.layers.core.Activation object at 0x000001EA19DF1748> True
# <keras.layers.merge.Concatenate object at 0x000001EA19E82860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19E1E668> True
# <keras.layers.core.Lambda object at 0x000001EA19EF4860> True
# <keras.layers.core.Activation object at 0x000001EA19F57630> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19FB0208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19FC9978> True
# <keras.layers.core.Activation object at 0x000001EA19FB0518> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A01AA20> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A0AD0F0> True
# <keras.layers.core.Activation object at 0x000001EA1A15BF28> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA19EC8BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A01A780> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA19F8BD68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A1A9E10> True
# <keras.layers.core.Activation object at 0x000001EA19F8B518> True
# <keras.layers.core.Activation object at 0x000001EA1A1D0630> True
# <keras.layers.merge.Concatenate object at 0x000001EA1A266748> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A200550> True
# <keras.layers.core.Lambda object at 0x000001EA1A2ACA20> True
# <keras.layers.core.Activation object at 0x000001EA1A33B4A8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A373FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A3B07B8> True
# <keras.layers.core.Activation object at 0x000001EA1A393978> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A4005C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A48E1D0> True
# <keras.layers.core.Activation object at 0x000001EA1A4FEF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A2ACEF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A53F940> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A373BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A571FD0> True
# <keras.layers.core.Activation object at 0x000001EA1A373E80> True
# <keras.layers.core.Activation object at 0x000001EA1A58DCF8> True
# <keras.layers.merge.Concatenate object at 0x000001EA1A5BC860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A5E42B0> True
# <keras.layers.core.Lambda object at 0x000001EA1A693FD0> True
# <keras.layers.core.Activation object at 0x000001EA1A71DC18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A754F28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A793630> True
# <keras.layers.core.Activation object at 0x000001EA1A7547F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A7DE208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A896F28> True
# <keras.layers.core.Activation object at 0x000001EA1A873668> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A6938D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A8C28D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A754A58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1A959E10> True
# <keras.layers.core.Activation object at 0x000001EA1A775470> True
# <keras.layers.core.Activation object at 0x000001EA1A923B00> True
# <keras.layers.merge.Concatenate object at 0x000001EA1A99CE10> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1A99CF60> True
# <keras.layers.core.Lambda object at 0x000001EA1AA7EC50> True
# <keras.layers.core.Activation object at 0x000001EA1AB0DB00> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AB34CF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AB774A8> True
# <keras.layers.core.Activation object at 0x000001EA1AB34DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1ABCB160> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AC58940> True
# <keras.layers.core.Activation object at 0x000001EA1AC77BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AA7EC88> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1ACAB710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AB348D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AD3AE48> True
# <keras.layers.core.Activation object at 0x000001EA1AB34F98> True
# <keras.layers.core.Activation object at 0x000001EA1AD08F28> True
# <keras.layers.merge.Concatenate object at 0x000001EA1AE13E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AD85048> True
# <keras.layers.core.Lambda object at 0x000001EA1AE5FA90> True
# <keras.layers.core.Activation object at 0x000001EA1AE5FAC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AF3FC88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AF5CE48> True
# <keras.layers.core.Activation object at 0x000001EA1AF1B470> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AF83F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B042780> True
# <keras.layers.core.Activation object at 0x000001EA1B065DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1AE5F6D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B0EEB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1AEF3D68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B121048> True
# <keras.layers.core.Activation object at 0x000001EA1AF1BC18> True
# <keras.layers.core.Activation object at 0x000001EA1B1C8FD0> True
# <keras.layers.merge.Concatenate object at 0x000001EA1B08E550> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B1F5C50> True
# <keras.layers.core.Lambda object at 0x000001EA1B230390> True
# <keras.layers.core.Activation object at 0x000001EA1B2309B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B31DC88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B303F60> True
# <keras.layers.core.Activation object at 0x000001EA1B2DF550> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B348CC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B3FA630> True
# <keras.layers.core.Activation object at 0x000001EA1B421898> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B2308D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B4AB9B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B2BBC18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B4D3390> True
# <keras.layers.core.Activation object at 0x000001EA1B2BBD68> True
# <keras.layers.core.Activation object at 0x000001EA1B4F0C50> True
# <keras.layers.merge.Concatenate object at 0x000001EA1B57C5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B5CBC88> True
# <keras.layers.core.Lambda object at 0x000001EA1B5F8E48> True
# <keras.layers.core.Activation object at 0x000001EA1B5F87B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B6B1400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B6D5E10> True
# <keras.layers.core.Activation object at 0x000001EA1B6B1BA8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B71ACF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B7D1470> True
# <keras.layers.core.Activation object at 0x000001EA1B7F96D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B5F8D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B88F7F0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B68BB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1B8B29E8> True
# <keras.layers.core.Activation object at 0x000001EA1B68BC50> True
# <keras.layers.core.Activation object at 0x000001EA1B8D2F98> True
# <keras.layers.merge.Concatenate object at 0x000001EA1B963AC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B82A5F8> True
# <keras.layers.core.Lambda object at 0x000001EA1B9DCD68> True
# <keras.layers.core.Activation object at 0x000001EA1B9DC320> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BA96240> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BAB9E10> True
# <keras.layers.core.Activation object at 0x000001EA1BA969E8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BB04400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BBB5E48> True
# <keras.layers.core.Activation object at 0x000001EA1BBDC5C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1B9DCB70> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BC746D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BA6BF60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BC9A898> True
# <keras.layers.core.Activation object at 0x000001EA1BA6BA90> True
# <keras.layers.core.Activation object at 0x000001EA1BCBAE80> True
# <keras.layers.merge.Concatenate object at 0x000001EA1BD45C18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BCE9668> True
# <keras.layers.core.Lambda object at 0x000001EA1BDE7F60> True
# <keras.layers.core.Activation object at 0x000001EA1BDE72B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BE77588> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BE97048> True
# <keras.layers.core.Activation object at 0x000001EA1BF05F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BF46BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BF7CF60> True
# <keras.layers.core.Activation object at 0x000001EA1C280320> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1BDC6BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C256FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1BE5DC88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C30D6D8> True
# <keras.layers.core.Activation object at 0x000001EA1BE5D748> True
# <keras.layers.core.Activation object at 0x000001EA1C332940> True
# <keras.layers.merge.Concatenate object at 0x000001EA1C3BBA58> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C35B860> True
# <keras.layers.core.Lambda object at 0x000001EA1C40AE48> True
# <keras.layers.core.Activation object at 0x000001EA1C456F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C4EC400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C50A358> True
# <keras.layers.core.Activation object at 0x000001EA1C52AC50> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C5B9860> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C5F0F60> True
# <keras.layers.core.Activation object at 0x000001EA1C556128> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C456E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C636D68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C4CDF60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C6EA588> True
# <keras.layers.core.Activation object at 0x000001EA1C4CD710> True
# <keras.layers.core.Activation object at 0x000001EA1C7147F0> True
# <keras.layers.merge.Concatenate object at 0x000001EA1C7A5908> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C73A710> True
# <keras.layers.core.Lambda object at 0x000001EA1C81C898> True
# <keras.layers.core.Activation object at 0x000001EA1C87C828> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C8D2240> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C8EF9B0> True
# <keras.layers.core.Activation object at 0x000001EA1C8D2550> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C93FA58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C9D3240> True
# <keras.layers.core.Activation object at 0x000001EA1C93F7B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1C7EBBE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CAAADD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1C8B0DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1CACE3C8> True
# <keras.layers.core.Activation object at 0x000001EA1C8B0550> True
# <keras.layers.core.Activation object at 0x000001EA1CAF6630> True
# <keras.layers.merge.Concatenate object at 0x000001EA1CB8B748> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CB29550> True
# <keras.layers.core.Lambda object at 0x000001EA1CBD2AC8> True
# <keras.layers.core.Activation object at 0x000001EA1CC5D550> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CCB8518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1CCD5860> True
# <keras.layers.core.Activation object at 0x000001EA1CCB85F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CD23668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1CDB5208> True
# <keras.layers.core.Activation object at 0x000001EA1CE23F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CBD2F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CE62940> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1CC93C50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1CE96F98> True
# <keras.layers.core.Activation object at 0x000001EA1CC93F28> True
# <keras.layers.core.Activation object at 0x000001EA1CEB2DA0> True
# <keras.layers.merge.Concatenate object at 0x000001EA1CED9E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CF0A080> True
# <keras.layers.core.Lambda object at 0x000001EA1CFBAF98> True
# <keras.layers.core.Activation object at 0x000001EA1D041CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D2BCF28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D372630> True
# <keras.layers.core.Activation object at 0x000001EA1D2BCF98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1CFBA978> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D164A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D3BD208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D07AA90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D1951D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D44D2E8> True
# <keras.layers.core.Activation object at 0x000001EA1D09B4A8> True
# <keras.layers.core.Activation object at 0x000001EA1D202F60> True
# <keras.layers.core.Activation object at 0x000001EA1D46EFD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D07AF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D240B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D4FDB00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D0B96A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D275EB8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D531E10> True
# <keras.layers.core.Activation object at 0x000001EA1D0DD908> True
# <keras.layers.core.Activation object at 0x000001EA1D28FE48> True
# <keras.layers.core.Activation object at 0x000001EA1D49BC18> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001EA1D575F28> True
# <keras.layers.merge.Concatenate object at 0x000001EA1D575710> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D676518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D70CE48> True
# <keras.layers.core.Activation object at 0x000001EA1D6E6EF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D7E2C50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D808DD8> True
# <keras.layers.core.Activation object at 0x000001EA1D82F5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D6295F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D8C6710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D652C18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1D8E88D0> True
# <keras.layers.core.Activation object at 0x000001EA1D691E80> True
# <keras.layers.core.Activation object at 0x000001EA1D90BEB8> True
# <keras.layers.merge.Concatenate object at 0x000001EA1D99CC50> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1D93B6A0> True
# <keras.layers.core.Lambda object at 0x000001EA1DA3C2E8> True
# <keras.layers.core.Activation object at 0x000001EA1DA1A8D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1DFEC5C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E00C048> True
# <keras.layers.core.Activation object at 0x000001EA1E0BABE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1DFEC8D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E0F0F98> True
# <keras.layers.core.Activation object at 0x000001EA1E05A0F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1DA1AA90> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E13A828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1DFC3CC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E1F2710> True
# <keras.layers.core.Activation object at 0x000001EA1DFC3780> True
# <keras.layers.core.Activation object at 0x000001EA1E214978> True
# <keras.layers.merge.Concatenate object at 0x000001EA1E29BA90> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E23D898> True
# <keras.layers.core.Lambda object at 0x000001EA1E2EFDD8> True
# <keras.layers.core.Activation object at 0x000001EA1E33EF98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E3D0438> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E3EF390> True
# <keras.layers.core.Activation object at 0x000001EA1E49D898> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E3D0748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E4D4FD0> True
# <keras.layers.core.Activation object at 0x000001EA1E438160> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E33EE80> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E51ADD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E3B2F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E5D05C0> True
# <keras.layers.core.Activation object at 0x000001EA1E3B2748> True
# <keras.layers.core.Activation object at 0x000001EA1E5F8828> True
# <keras.layers.merge.Concatenate object at 0x000001EA1E68F940> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E61F748> True
# <keras.layers.core.Lambda object at 0x000001EA1E6D2F60> True
# <keras.layers.core.Activation object at 0x000001EA1E6D2BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E7B9278> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E7D49E8> True
# <keras.layers.core.Activation object at 0x000001EA1E7B9588> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E826A90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E8B9278> True
# <keras.layers.core.Activation object at 0x000001EA1E8267F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E6D2C88> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1E98FE10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E796DD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1E9B2400> True
# <keras.layers.core.Activation object at 0x000001EA1E796588> True
# <keras.layers.core.Activation object at 0x000001EA1E9DB668> True
# <keras.layers.merge.Concatenate object at 0x000001EA1EA70780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EA0E588> True
# <keras.layers.core.Lambda object at 0x000001EA1EAB5F28> True
# <keras.layers.core.Activation object at 0x000001EA1EB42588> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EB9D550> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1EBB7898> True
# <keras.layers.core.Activation object at 0x000001EA1EB9D630> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EC096A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1EC99048> True
# <keras.layers.core.Activation object at 0x000001EA1ED08F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EAB5AC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1ED47BE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1EB77C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1ED7AFD0> True
# <keras.layers.core.Activation object at 0x000001EA1EB77F60> True
# <keras.layers.core.Activation object at 0x000001EA1EDBDE10> True
# <keras.layers.merge.Concatenate object at 0x000001EA1EE54668> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EDEE588> True
# <keras.layers.core.Lambda object at 0x000001EA1EE9EFD0> True
# <keras.layers.core.Activation object at 0x000001EA1EF28CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EF5CF98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1EF9C6D8> True
# <keras.layers.core.Activation object at 0x000001EA1EF5C860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EFE7240> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F07C320> True
# <keras.layers.core.Activation object at 0x000001EA1F12A630> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EE9E9B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1EFE74E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1EF5CAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F15FEF0> True
# <keras.layers.core.Activation object at 0x000001EA1EF7F4E0> True
# <keras.layers.core.Activation object at 0x000001EA1F0C9160> True
# <keras.layers.merge.Concatenate object at 0x000001EA1F1A7F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F1A7780> True
# <keras.layers.core.Lambda object at 0x000001EA1F281C88> True
# <keras.layers.core.Activation object at 0x000001EA1F30BB38> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F33EE48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F37D550> True
# <keras.layers.core.Activation object at 0x000001EA1F33E710> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F3CD128> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F4609E8> True
# <keras.layers.core.Activation object at 0x000001EA1F47FB00> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F281CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F4B27B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F33E978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F546EF0> True
# <keras.layers.core.Activation object at 0x000001EA1F365390> True
# <keras.layers.core.Activation object at 0x000001EA1F50DFD0> True
# <keras.layers.merge.Concatenate object at 0x000001EA1F58A160> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F58A0F0> True
# <keras.layers.core.Lambda object at 0x000001EA1F667B38> True
# <keras.layers.core.Activation object at 0x000001EA1F667B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F748DD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F760400> True
# <keras.layers.core.Activation object at 0x000001EA1F722C18> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F7BB208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F847828> True
# <keras.layers.core.Activation object at 0x000001EA1F86DE48> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F667780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F8F6BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F7223C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1F924208> True
# <keras.layers.core.Activation object at 0x000001EA1F722F98> True
# <keras.layers.core.Activation object at 0x000001EA1F8965F8> True
# <keras.layers.merge.Concatenate object at 0x000001EA1FA08CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1F9739B0> True
# <keras.layers.core.Lambda object at 0x000001EA1FA4A978> True
# <keras.layers.core.Activation object at 0x000001EA1FA4A4E0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FB44D30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FB26F98> True
# <keras.layers.core.Activation object at 0x000001EA1FB045F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FB6CEB8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FC286D8> True
# <keras.layers.core.Activation object at 0x000001EA1FC4B940> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FA4A5C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FCD8A58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FAE0F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FD06208> True
# <keras.layers.core.Activation object at 0x000001EA1FAE0D30> True
# <keras.layers.core.Activation object at 0x000001EA1FD76EF0> True
# <keras.layers.merge.Concatenate object at 0x000001EA1FE06D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FDB46A0> True
# <keras.layers.core.Lambda object at 0x000001EA1FDEAF98> True
# <keras.layers.core.Activation object at 0x000001EA1FE2A860> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FF26E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FF0CEB8> True
# <keras.layers.core.Activation object at 0x000001EA1FEE64A8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FF53C18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA2000A518> True
# <keras.layers.core.Activation object at 0x000001EA20034780> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA1FE2A898> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA200C4898> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA1FEC1BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA200EBEB8> True
# <keras.layers.core.Activation object at 0x000001EA1FEC1CF8> True
# <keras.layers.core.Activation object at 0x000001EA2010EBE0> True
# <keras.layers.merge.Concatenate object at 0x000001EA201EBDD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA2019CB70> True
# <keras.layers.core.Lambda object at 0x000001EA2023F320> True
# <keras.layers.convolutional.Conv2D object at 0x000001EA20216CC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001EA202A3588> True
# <keras.layers.core.Activation object at 0x000001EA202A3A20> True

# %%
#   first: train only the top layers (which were randomly initialized)
#   i.e. freeze all convolutional  layers
for layer in base_model.layers:
    layer.trainable = True

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# %%
y_train_one_hot = tf.one_hot( y_train, n_classes ).eval()

# %%
data_train_gen = data_generator(sess, X_train, y_train_one_hot )

# %%
print( data_train_gen )
# Out:
# <function data_generator.<locals>.generator at 0x000001EA2ADB1840>

# %%
# train the model on the new data for a "few" epochs
model.fit_generator(data_train_gen(), n_training/batch_size, verbose=1)
# Out:
# Epoch 1/1
#   1/781 [..............................] - ETA: 29:01:28 - loss: 2.4110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-9228e124d14e> in <module>
#       1 # train the model on the new data for a "few" epochs
# ----> 2 model.fit_generator(data_train_gen(), n_training/batch_size, verbose=1)
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Validation

# %%
#resize images
images_resized = sess.run(tf_resize_op, {batch_of_images_placeholder: X_test})
images = preprocess_input(images_resized)

# %%
print( images.shape )
# Out:
# (10000, 224, 224, 3)

# %%
result = base_model.predict(images, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-5170a95ce0d5> in <module>
# ----> 1 result = base_model.predict(images, verbose=2)
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
y_pred = [ np.argmax( result[i] ) for i in range(n_testing) ]

# %%
np.sum( y_pred == y_test ) / n_testing

# %%
# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.001, momentum=0.9), loss='categorical_crossentropy')

# %%
model.fit_generator(data_train_gen(), n_training/batch_size, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 782/781 [==============================] - 451s 576ms/step - loss: 0.2688
# Epoch 2/10
# 782/781 [==============================] - 447s 572ms/step - loss: 0.0647
# Epoch 3/10
# 782/781 [==============================] - 446s 570ms/step - loss: 0.0170
# Epoch 4/10
# 782/781 [==============================] - 453s 580ms/step - loss: 0.0059
# Epoch 5/10
# 782/781 [==============================] - 455s 581ms/step - loss: 0.0029
# Epoch 6/10
# 782/781 [==============================] - 455s 582ms/step - loss: 0.0018
# Epoch 7/10
# 782/781 [==============================] - 456s 584ms/step - loss: 0.0011
# Epoch 8/10
# 782/781 [==============================] - 451s 577ms/step - loss: 7.8778e-04
# Epoch 9/10
# 782/781 [==============================] - 466s 596ms/step - loss: 6.1613e-04
# Epoch 10/10
# 782/781 [==============================] - 452s 578ms/step - loss: 5.0233e-04

# %%
result = model.predict(images, verbose=1)
y_pred = [ np.argmax( result[i] ) for i in range(n_testing) ]
np.sum( y_pred == y_test ) / n_testing
# Out:
# 10000/10000 [==============================] - 43s 4ms/step
# 0.9383
