# %%
import time
#import myutils
import numpy as np
import tensorflow as tf
from keras.layers import Input, Dense, AveragePooling2D, GlobalAveragePooling2D
from keras import backend as K
from keras.models import Model
from keras.applications.inception_resnet_v2 import InceptionResNetV2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load CIFAR10 data
# Here we use [keras.datasets](https://keras.io/datasets/) which is pretty similar to our <tt>myutils.load_CIFAR10_dataset()</tt> procedure.

# %%
n_classes = 10
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

n_training = X_train.shape[0]
n_testing = X_test.shape[0]

y_train = y_train.flatten()
y_test  = y_test.flatten()

print( X_train.shape, y_train.shape,  X_test.shape, y_test.shape )

from matplotlib import pyplot as plt
plt.imshow( X_train[0]  )
plt.show()
# Out:
# (50000, 32, 32, 3) (50000,) (10000, 32, 32, 3) (10000,)

# %% [markdown]
# # Create model

# %%
from keras.models import Model
from keras.applications.inception_resnet_v2 import InceptionResNetV2

network_names = [ 'incv2' ]

print("Available networks = ", network_names)
cnnid = 0; # int( input("Please choose the CNN network [0-{n}]: ".format(n=len(network_names)-1)) )

selected_network = network_names[cnnid]
print("Selected network: ", selected_network)

input_shape = {
    'incv2'   : (224,224,3)
}[selected_network]

def create_model_incv2():
    tf_input = Input(shape=input_shape)
    base_model = InceptionResNetV2(input_tensor=tf_input, weights='imagenet', include_top=False)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(n_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return base_model, model

create_model = {
    'incv2'    : create_model_incv2
}[selected_network]
# Out:
# Available networks =  ['incv2']
# Selected network:  incv2

# %% [markdown]
# # Data generator for tensorflow
#
# The feature extraction can process the batches of data. It is common in feeding neural networks in tensorflow.

# %%
# tensorflow placeholder for batch of images from CIFAR10 dataset
batch_of_images_placeholder = tf.placeholder("uint8", (None, 32, 32, 3))

batch_size = 64

tf_resize_op = tf.image.resize_images(batch_of_images_placeholder, (224,224), method=0)

# %%
print( X_train.shape, y_train.shape,  X_test.shape, y_test.shape )
# Out:
# (50000, 32, 32, 3) (50000,) (10000, 32, 32, 3) (10000,)

# %%
# data generator for tensorflow session
from keras.applications.inception_resnet_v2 import preprocess_input as incv2_preprocess_input

preprocess_input =  incv2_preprocess_input

def data_generator(sess,data,labels):
    def generator():
        start = 0
        end = start + batch_size
        n = data.shape[0]
        while True:
            batch_of_images_resized = sess.run(tf_resize_op, {batch_of_images_placeholder: data[start:end]})
            batch_of_images__preprocessed = preprocess_input(batch_of_images_resized)
            batch_of_labels = labels[start:end]
            
            start += batch_size
            end   += batch_size
            if start >= n:
                start = 0
                end = batch_size
            yield (batch_of_images__preprocessed, batch_of_labels)
    return generator

# %% [markdown]
# # Create model

# %%
sess = tf.InteractiveSession()

# %%
K.set_session(sess)
K.set_learning_phase(1)  # 0 - test,  1 - train

# %%
base_model, model = create_model()

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed_5b
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# 50 conv2d_13
# 51 conv2d_15
# 52 conv2d_18
# 53 batch_normalization_13
# 54 batch_normalization_15
# 55 batch_normalization_18
# 56 activation_13
# 57 activation_15
# 58 activation_18
# 59 block35_1_mixed
# 60 block35_1_conv
# 61 block35_1
# 62 block35_1_ac
# 63 conv2d_22
# 64 batch_normalization_22
# 65 activation_22
# 66 conv2d_20
# 67 conv2d_23
# 68 batch_normalization_20
# 69 batch_normalization_23
# 70 activation_20
# 71 activation_23
# 72 conv2d_19
# 73 conv2d_21
# 74 conv2d_24
# 75 batch_normalization_19
# 76 batch_normalization_21
# 77 batch_normalization_24
# 78 activation_19
# 79 activation_21
# 80 activation_24
# 81 block35_2_mixed
# 82 block35_2_conv
# 83 block35_2
# 84 block35_2_ac
# 85 conv2d_28
# 86 batch_normalization_28
# 87 activation_28
# 88 conv2d_26
# 89 conv2d_29
# 90 batch_normalization_26
# 91 batch_normalization_29
# 92 activation_26
# 93 activation_29
# 94 conv2d_25
# 95 conv2d_27
# 96 conv2d_30
# 97 batch_normalization_25
# 98 batch_normalization_27
# 99 batch_normalization_30
# 100 activation_25
# 101 activation_27
# 102 activation_30
# 103 block35_3_mixed
# 104 block35_3_conv
# 105 block35_3
# 106 block35_3_ac
# 107 conv2d_34
# 108 batch_normalization_34
# 109 activation_34
# 110 conv2d_32
# 111 conv2d_35
# 112 batch_normalization_32
# 113 batch_normalization_35
# 114 activation_32
# 115 activation_35
# 116 conv2d_31
# 117 conv2d_33
# 118 conv2d_36
# 119 batch_normalization_31
# 120 batch_normalization_33
# 121 batch_normalization_36
# 122 activation_31
# 123 activation_33
# 124 activation_36
# 125 block35_4_mixed
# 126 block35_4_conv
# 127 block35_4
# 128 block35_4_ac
# 129 conv2d_40
# 130 batch_normalization_40
# 131 activation_40
# 132 conv2d_38
# 133 conv2d_41
# 134 batch_normalization_38
# 135 batch_normalization_41
# 136 activation_38
# 137 activation_41
# 138 conv2d_37
# 139 conv2d_39
# 140 conv2d_42
# 141 batch_normalization_37
# 142 batch_normalization_39
# 143 batch_normalization_42
# 144 activation_37
# 145 activation_39
# 146 activation_42
# 147 block35_5_mixed
# 148 block35_5_conv
# 149 block35_5
# 150 block35_5_ac
# 151 conv2d_46
# 152 batch_normalization_46
# 153 activation_46
# 154 conv2d_44
# 155 conv2d_47
# 156 batch_normalization_44
# 157 batch_normalization_47
# 158 activation_44
# 159 activation_47
# 160 conv2d_43
# 161 conv2d_45
# 162 conv2d_48
# 163 batch_normalization_43
# 164 batch_normalization_45
# 165 batch_normalization_48
# 166 activation_43
# 167 activation_45
# 168 activation_48
# 169 block35_6_mixed
# 170 block35_6_conv
# 171 block35_6
# 172 block35_6_ac
# 173 conv2d_52
# 174 batch_normalization_52
# 175 activation_52
# 176 conv2d_50
# 177 conv2d_53
# 178 batch_normalization_50
# 179 batch_normalization_53
# 180 activation_50
# 181 activation_53
# 182 conv2d_49
# 183 conv2d_51
# 184 conv2d_54
# 185 batch_normalization_49
# 186 batch_normalization_51
# 187 batch_normalization_54
# 188 activation_49
# 189 activation_51
# 190 activation_54
# 191 block35_7_mixed
# 192 block35_7_conv
# 193 block35_7
# 194 block35_7_ac
# 195 conv2d_58
# 196 batch_normalization_58
# 197 activation_58
# 198 conv2d_56
# 199 conv2d_59
# 200 batch_normalization_56
# 201 batch_normalization_59
# 202 activation_56
# 203 activation_59
# 204 conv2d_55
# 205 conv2d_57
# 206 conv2d_60
# 207 batch_normalization_55
# 208 batch_normalization_57
# 209 batch_normalization_60
# 210 activation_55
# 211 activation_57
# 212 activation_60
# 213 block35_8_mixed
# 214 block35_8_conv
# 215 block35_8
# 216 block35_8_ac
# 217 conv2d_64
# 218 batch_normalization_64
# 219 activation_64
# 220 conv2d_62
# 221 conv2d_65
# 222 batch_normalization_62
# 223 batch_normalization_65
# 224 activation_62
# 225 activation_65
# 226 conv2d_61
# 227 conv2d_63
# 228 conv2d_66
# 229 batch_normalization_61
# 230 batch_normalization_63
# 231 batch_normalization_66
# 232 activation_61
# 233 activation_63
# 234 activation_66
# 235 block35_9_mixed
# 236 block35_9_conv
# 237 block35_9
# 238 block35_9_ac
# 239 conv2d_70
# 240 batch_normalization_70
# 241 activation_70
# 242 conv2d_68
# 243 conv2d_71
# 244 batch_normalization_68
# 245 batch_normalization_71
# 246 activation_68
# 247 activation_71
# 248 conv2d_67
# 249 conv2d_69
# 250 conv2d_72
# 251 batch_normalization_67
# 252 batch_normalization_69
# 253 batch_normalization_72
# 254 activation_67
# 255 activation_69
# 256 activation_72
# 257 block35_10_mixed
# 258 block35_10_conv
# 259 block35_10
# 260 block35_10_ac
# 261 conv2d_74
# 262 batch_normalization_74
# 263 activation_74
# 264 conv2d_75
# 265 batch_normalization_75
# 266 activation_75
# 267 conv2d_73
# 268 conv2d_76
# 269 batch_normalization_73
# 270 batch_normalization_76
# 271 activation_73
# 272 activation_76
# 273 max_pooling2d_3
# 274 mixed_6a
# 275 conv2d_78
# 276 batch_normalization_78
# 277 activation_78
# 278 conv2d_79
# 279 batch_normalization_79
# 280 activation_79
# 281 conv2d_77
# 282 conv2d_80
# 283 batch_normalization_77
# 284 batch_normalization_80
# 285 activation_77
# 286 activation_80
# 287 block17_1_mixed
# 288 block17_1_conv
# 289 block17_1
# 290 block17_1_ac
# 291 conv2d_82
# 292 batch_normalization_82
# 293 activation_82
# 294 conv2d_83
# 295 batch_normalization_83
# 296 activation_83
# 297 conv2d_81
# 298 conv2d_84
# 299 batch_normalization_81
# 300 batch_normalization_84
# 301 activation_81
# 302 activation_84
# 303 block17_2_mixed
# 304 block17_2_conv
# 305 block17_2
# 306 block17_2_ac
# 307 conv2d_86
# 308 batch_normalization_86
# 309 activation_86
# 310 conv2d_87
# 311 batch_normalization_87
# 312 activation_87
# 313 conv2d_85
# 314 conv2d_88
# 315 batch_normalization_85
# 316 batch_normalization_88
# 317 activation_85
# 318 activation_88
# 319 block17_3_mixed
# 320 block17_3_conv
# 321 block17_3
# 322 block17_3_ac
# 323 conv2d_90
# 324 batch_normalization_90
# 325 activation_90
# 326 conv2d_91
# 327 batch_normalization_91
# 328 activation_91
# 329 conv2d_89
# 330 conv2d_92
# 331 batch_normalization_89
# 332 batch_normalization_92
# 333 activation_89
# 334 activation_92
# 335 block17_4_mixed
# 336 block17_4_conv
# 337 block17_4
# 338 block17_4_ac
# 339 conv2d_94
# 340 batch_normalization_94
# 341 activation_94
# 342 conv2d_95
# 343 batch_normalization_95
# 344 activation_95
# 345 conv2d_93
# 346 conv2d_96
# 347 batch_normalization_93
# 348 batch_normalization_96
# 349 activation_93
# 350 activation_96
# 351 block17_5_mixed
# 352 block17_5_conv
# 353 block17_5
# 354 block17_5_ac
# 355 conv2d_98
# 356 batch_normalization_98
# 357 activation_98
# 358 conv2d_99
# 359 batch_normalization_99
# 360 activation_99
# 361 conv2d_97
# 362 conv2d_100
# 363 batch_normalization_97
# 364 batch_normalization_100
# 365 activation_97
# 366 activation_100
# 367 block17_6_mixed
# 368 block17_6_conv
# 369 block17_6
# 370 block17_6_ac
# 371 conv2d_102
# 372 batch_normalization_102
# 373 activation_102
# 374 conv2d_103
# 375 batch_normalization_103
# 376 activation_103
# 377 conv2d_101
# 378 conv2d_104
# 379 batch_normalization_101
# 380 batch_normalization_104
# 381 activation_101
# 382 activation_104
# 383 block17_7_mixed
# 384 block17_7_conv
# 385 block17_7
# 386 block17_7_ac
# 387 conv2d_106
# 388 batch_normalization_106
# 389 activation_106
# 390 conv2d_107
# 391 batch_normalization_107
# 392 activation_107
# 393 conv2d_105
# 394 conv2d_108
# 395 batch_normalization_105
# 396 batch_normalization_108
# 397 activation_105
# 398 activation_108
# 399 block17_8_mixed
# 400 block17_8_conv
# 401 block17_8
# 402 block17_8_ac
# 403 conv2d_110
# 404 batch_normalization_110
# 405 activation_110
# 406 conv2d_111
# 407 batch_normalization_111
# 408 activation_111
# 409 conv2d_109
# 410 conv2d_112
# 411 batch_normalization_109
# 412 batch_normalization_112
# 413 activation_109
# 414 activation_112
# 415 block17_9_mixed
# 416 block17_9_conv
# 417 block17_9
# 418 block17_9_ac
# 419 conv2d_114
# 420 batch_normalization_114
# 421 activation_114
# 422 conv2d_115
# 423 batch_normalization_115
# 424 activation_115
# 425 conv2d_113
# 426 conv2d_116
# 427 batch_normalization_113
# 428 batch_normalization_116
# 429 activation_113
# 430 activation_116
# 431 block17_10_mixed
# 432 block17_10_conv
# 433 block17_10
# 434 block17_10_ac
# 435 conv2d_118
# 436 batch_normalization_118
# 437 activation_118
# 438 conv2d_119
# 439 batch_normalization_119
# 440 activation_119
# 441 conv2d_117
# 442 conv2d_120
# 443 batch_normalization_117
# 444 batch_normalization_120
# 445 activation_117
# 446 activation_120
# 447 block17_11_mixed
# 448 block17_11_conv
# 449 block17_11
# 450 block17_11_ac
# 451 conv2d_122
# 452 batch_normalization_122
# 453 activation_122
# 454 conv2d_123
# 455 batch_normalization_123
# 456 activation_123
# 457 conv2d_121
# 458 conv2d_124
# 459 batch_normalization_121
# 460 batch_normalization_124
# 461 activation_121
# 462 activation_124
# 463 block17_12_mixed
# 464 block17_12_conv
# 465 block17_12
# 466 block17_12_ac
# 467 conv2d_126
# 468 batch_normalization_126
# 469 activation_126
# 470 conv2d_127
# 471 batch_normalization_127
# 472 activation_127
# 473 conv2d_125
# 474 conv2d_128
# 475 batch_normalization_125
# 476 batch_normalization_128
# 477 activation_125
# 478 activation_128
# 479 block17_13_mixed
# 480 block17_13_conv
# 481 block17_13
# 482 block17_13_ac
# 483 conv2d_130
# 484 batch_normalization_130
# 485 activation_130
# 486 conv2d_131
# 487 batch_normalization_131
# 488 activation_131
# 489 conv2d_129
# 490 conv2d_132
# 491 batch_normalization_129
# 492 batch_normalization_132
# 493 activation_129
# 494 activation_132
# 495 block17_14_mixed
# 496 block17_14_conv
# 497 block17_14
# 498 block17_14_ac
# 499 conv2d_134
# 500 batch_normalization_134
# 501 activation_134
# 502 conv2d_135
# 503 batch_normalization_135
# 504 activation_135
# 505 conv2d_133
# 506 conv2d_136
# 507 batch_normalization_133
# 508 batch_normalization_136
# 509 activation_133
# 510 activation_136
# 511 block17_15_mixed
# 512 block17_15_conv
# 513 block17_15
# 514 block17_15_ac
# 515 conv2d_138
# 516 batch_normalization_138
# 517 activation_138
# 518 conv2d_139
# 519 batch_normalization_139
# 520 activation_139
# 521 conv2d_137
# 522 conv2d_140
# 523 batch_normalization_137
# 524 batch_normalization_140
# 525 activation_137
# 526 activation_140
# 527 block17_16_mixed
# 528 block17_16_conv
# 529 block17_16
# 530 block17_16_ac
# 531 conv2d_142
# 532 batch_normalization_142
# 533 activation_142
# 534 conv2d_143
# 535 batch_normalization_143
# 536 activation_143
# 537 conv2d_141
# 538 conv2d_144
# 539 batch_normalization_141
# 540 batch_normalization_144
# 541 activation_141
# 542 activation_144
# 543 block17_17_mixed
# 544 block17_17_conv
# 545 block17_17
# 546 block17_17_ac
# 547 conv2d_146
# 548 batch_normalization_146
# 549 activation_146
# 550 conv2d_147
# 551 batch_normalization_147
# 552 activation_147
# 553 conv2d_145
# 554 conv2d_148
# 555 batch_normalization_145
# 556 batch_normalization_148
# 557 activation_145
# 558 activation_148
# 559 block17_18_mixed
# 560 block17_18_conv
# 561 block17_18
# 562 block17_18_ac
# 563 conv2d_150
# 564 batch_normalization_150
# 565 activation_150
# 566 conv2d_151
# 567 batch_normalization_151
# 568 activation_151
# 569 conv2d_149
# 570 conv2d_152
# 571 batch_normalization_149
# 572 batch_normalization_152
# 573 activation_149
# 574 activation_152
# 575 block17_19_mixed
# 576 block17_19_conv
# 577 block17_19
# 578 block17_19_ac
# 579 conv2d_154
# 580 batch_normalization_154
# 581 activation_154
# 582 conv2d_155
# 583 batch_normalization_155
# 584 activation_155
# 585 conv2d_153
# 586 conv2d_156
# 587 batch_normalization_153
# 588 batch_normalization_156
# 589 activation_153
# 590 activation_156
# 591 block17_20_mixed
# 592 block17_20_conv
# 593 block17_20
# 594 block17_20_ac
# 595 conv2d_161
# 596 batch_normalization_161
# 597 activation_161
# 598 conv2d_157
# 599 conv2d_159
# 600 conv2d_162
# 601 batch_normalization_157
# 602 batch_normalization_159
# 603 batch_normalization_162
# 604 activation_157
# 605 activation_159
# 606 activation_162
# 607 conv2d_158
# 608 conv2d_160
# 609 conv2d_163
# 610 batch_normalization_158
# 611 batch_normalization_160
# 612 batch_normalization_163
# 613 activation_158
# 614 activation_160
# 615 activation_163
# 616 max_pooling2d_4
# 617 mixed_7a
# 618 conv2d_165
# 619 batch_normalization_165
# 620 activation_165
# 621 conv2d_166
# 622 batch_normalization_166
# 623 activation_166
# 624 conv2d_164
# 625 conv2d_167
# 626 batch_normalization_164
# 627 batch_normalization_167
# 628 activation_164
# 629 activation_167
# 630 block8_1_mixed
# 631 block8_1_conv
# 632 block8_1
# 633 block8_1_ac
# 634 conv2d_169
# 635 batch_normalization_169
# 636 activation_169
# 637 conv2d_170
# 638 batch_normalization_170
# 639 activation_170
# 640 conv2d_168
# 641 conv2d_171
# 642 batch_normalization_168
# 643 batch_normalization_171
# 644 activation_168
# 645 activation_171
# 646 block8_2_mixed
# 647 block8_2_conv
# 648 block8_2
# 649 block8_2_ac
# 650 conv2d_173
# 651 batch_normalization_173
# 652 activation_173
# 653 conv2d_174
# 654 batch_normalization_174
# 655 activation_174
# 656 conv2d_172
# 657 conv2d_175
# 658 batch_normalization_172
# 659 batch_normalization_175
# 660 activation_172
# 661 activation_175
# 662 block8_3_mixed
# 663 block8_3_conv
# 664 block8_3
# 665 block8_3_ac
# 666 conv2d_177
# 667 batch_normalization_177
# 668 activation_177
# 669 conv2d_178
# 670 batch_normalization_178
# 671 activation_178
# 672 conv2d_176
# 673 conv2d_179
# 674 batch_normalization_176
# 675 batch_normalization_179
# 676 activation_176
# 677 activation_179
# 678 block8_4_mixed
# 679 block8_4_conv
# 680 block8_4
# 681 block8_4_ac
# 682 conv2d_181
# 683 batch_normalization_181
# 684 activation_181
# 685 conv2d_182
# 686 batch_normalization_182
# 687 activation_182
# 688 conv2d_180
# 689 conv2d_183
# 690 batch_normalization_180
# 691 batch_normalization_183
# 692 activation_180
# 693 activation_183
# 694 block8_5_mixed
# 695 block8_5_conv
# 696 block8_5
# 697 block8_5_ac
# 698 conv2d_185
# 699 batch_normalization_185
# 700 activation_185
# 701 conv2d_186
# 702 batch_normalization_186
# 703 activation_186
# 704 conv2d_184
# 705 conv2d_187
# 706 batch_normalization_184
# 707 batch_normalization_187
# 708 activation_184
# 709 activation_187
# 710 block8_6_mixed
# 711 block8_6_conv
# 712 block8_6
# 713 block8_6_ac
# 714 conv2d_189
# 715 batch_normalization_189
# 716 activation_189
# 717 conv2d_190
# 718 batch_normalization_190
# 719 activation_190
# 720 conv2d_188
# 721 conv2d_191
# 722 batch_normalization_188
# 723 batch_normalization_191
# 724 activation_188
# 725 activation_191
# 726 block8_7_mixed
# 727 block8_7_conv
# 728 block8_7
# 729 block8_7_ac
# 730 conv2d_193
# 731 batch_normalization_193
# 732 activation_193
# 733 conv2d_194
# 734 batch_normalization_194
# 735 activation_194
# 736 conv2d_192
# 737 conv2d_195
# 738 batch_normalization_192
# 739 batch_normalization_195
# 740 activation_192
# 741 activation_195
# 742 block8_8_mixed
# 743 block8_8_conv
# 744 block8_8
# 745 block8_8_ac
# 746 conv2d_197
# 747 batch_normalization_197
# 748 activation_197
# 749 conv2d_198
# 750 batch_normalization_198
# 751 activation_198
# 752 conv2d_196
# 753 conv2d_199
# 754 batch_normalization_196
# 755 batch_normalization_199
# 756 activation_196
# 757 activation_199
# 758 block8_9_mixed
# 759 block8_9_conv
# 760 block8_9
# 761 block8_9_ac
# 762 conv2d_201
# 763 batch_normalization_201
# 764 activation_201
# 765 conv2d_202
# 766 batch_normalization_202
# 767 activation_202
# 768 conv2d_200
# 769 conv2d_203
# 770 batch_normalization_200
# 771 batch_normalization_203
# 772 activation_200
# 773 activation_203
# 774 block8_10_mixed
# 775 block8_10_conv
# 776 block8_10
# 777 conv_7b
# 778 conv_7b_bn
# 779 conv_7b_ac

# %%
for layer in base_model.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001BC119BB080> False
# <keras.layers.convolutional.Conv2D object at 0x000001BC118009B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC119BB0F0> True
# <keras.layers.core.Activation object at 0x000001BC0C8600F0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC1B632E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4698DF98> True
# <keras.layers.core.Activation object at 0x000001BC469B1B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48A18C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48A8FFD0> True
# <keras.layers.core.Activation object at 0x000001BC48AE5320> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001BC48B25240> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48A70A90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48C01208> True
# <keras.layers.core.Activation object at 0x000001BC48B69E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48BB8E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48C66C18> True
# <keras.layers.core.Activation object at 0x000001BC48CCFD68> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001BC48CF7F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48EF85C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC49FA5AC8> True
# <keras.layers.core.Activation object at 0x000001BC49FEADD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48D6ABE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC08FF7BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48E42518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC1B5799B0> True
# <keras.layers.core.Activation object at 0x000001BC48E65CF8> True
# <keras.layers.core.Activation object at 0x000001BC1B59C0F0> True
# <keras.layers.pooling.AveragePooling2D object at 0x000001BC4A1BD208> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48C47E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC48E27828> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC1B5DE550> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A16FF60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48DD8A58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC48F1DF98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A195B70> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A2BA9E8> True
# <keras.layers.core.Activation object at 0x000001BC48D95550> True
# <keras.layers.core.Activation object at 0x000001BC48E27B70> True
# <keras.layers.core.Activation object at 0x000001BC4A147E48> True
# <keras.layers.core.Activation object at 0x000001BC4A2DFDD8> True
# <keras.layers.merge.Concatenate object at 0x000001BC4A24FBE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A5B7CF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A5E1D30> True
# <keras.layers.core.Activation object at 0x000001BC4A69E518> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A36E320> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A6086A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A400E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A6AFD30> True
# <keras.layers.core.Activation object at 0x000001BC4A448E48> True
# <keras.layers.core.Activation object at 0x000001BC4A707E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A294AC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A426710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A6E6F28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A3AEAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A58FE10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A7E9E10> True
# <keras.layers.core.Activation object at 0x000001BC4A345BA8> True
# <keras.layers.core.Activation object at 0x000001BC4A58FA20> True
# <keras.layers.core.Activation object at 0x000001BC4A781550> True
# <keras.layers.merge.Concatenate object at 0x000001BC4A7CF3C8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A7CFD30> True
# <keras.layers.core.Lambda object at 0x000001BC4A8A4F98> True
# <keras.layers.core.Activation object at 0x000001BC4A961B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AB7BEB8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4ABCCF60> True
# <keras.layers.core.Activation object at 0x000001BC4ABCCB00> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A9ABCC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4ABB25C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A9E8FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4ACAFF98> True
# <keras.layers.core.Activation object at 0x000001BC4A9E8198> True
# <keras.layers.core.Activation object at 0x000001BC4AD1BDD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4A8A4908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AA40438> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AD47F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4A972DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4AAA6978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4AD68C18> True
# <keras.layers.core.Activation object at 0x000001BC4A972E10> True
# <keras.layers.core.Activation object at 0x000001BC4A9CB2B0> True
# <keras.layers.core.Activation object at 0x000001BC4ADB0FD0> True
# <keras.layers.merge.Concatenate object at 0x000001BC4AD8C5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4ADF9FD0> True
# <keras.layers.core.Lambda object at 0x000001BC4AE769B0> True
# <keras.layers.core.Activation object at 0x000001BC4AE8D9E8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B075BE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B19BB38> True
# <keras.layers.core.Activation object at 0x000001BC4B150DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AF547B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B1C47B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4AF71DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B21DDD8> True
# <keras.layers.core.Activation object at 0x000001BC4B0039E8> True
# <keras.layers.core.Activation object at 0x000001BC4B274C88> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AE8DD30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4AF95D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B2515F8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4AF54668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B090630> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B353FD0> True
# <keras.layers.core.Activation object at 0x000001BC4AF54CF8> True
# <keras.layers.core.Activation object at 0x000001BC4AF95F60> True
# <keras.layers.core.Activation object at 0x000001BC4B337E80> True
# <keras.layers.merge.Concatenate object at 0x000001BC4B337748> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B337CF8> True
# <keras.layers.core.Lambda object at 0x000001BC4B412780> True
# <keras.layers.core.Activation object at 0x000001BC4B4D3400> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B637E48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B739BA8> True
# <keras.layers.core.Activation object at 0x000001BC4B761358> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B519630> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B721EB8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B558C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B81AD68> True
# <keras.layers.core.Activation object at 0x000001BC4B53DF98> True
# <keras.layers.core.Activation object at 0x000001BC4B7219E8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B412F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B53D668> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B7F1C18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B4E1E48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B5FFDD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4B8D7D68> True
# <keras.layers.core.Activation object at 0x000001BC4B4E1E10> True
# <keras.layers.core.Activation object at 0x000001BC4B657B70> True
# <keras.layers.core.Activation object at 0x000001BC4B968FD0> True
# <keras.layers.merge.Concatenate object at 0x000001BC4B946588> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B9AACF8> True
# <keras.layers.core.Lambda object at 0x000001BC4B9E2898> True
# <keras.layers.core.Activation object at 0x000001BC4B9E2400> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BC92EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BD07C18> True
# <keras.layers.core.Activation object at 0x000001BC4BCBCE80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BAB4908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BD314E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BADEBE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BD8CE10> True
# <keras.layers.core.Activation object at 0x000001BC4BB1CC18> True
# <keras.layers.core.Activation object at 0x000001BC4BDE2B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4B9E2FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BB81978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BDC3278> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BAB47B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BBFEF60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4BEC15F8> True
# <keras.layers.core.Activation object at 0x000001BC4BAB4898> True
# <keras.layers.core.Activation object at 0x000001BC4BC66BE0> True
# <keras.layers.core.Activation object at 0x000001BC4BF2BBA8> True
# <keras.layers.merge.Concatenate object at 0x000001BC4BF58E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4BEA3C50> True
# <keras.layers.core.Lambda object at 0x000001BC4BF81898> True
# <keras.layers.core.Activation object at 0x000001BC4BF81E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C1A7BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4C2C9438> True
# <keras.layers.core.Activation object at 0x000001BC4C2C9CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C0887B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C28EBE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4C0AAD30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4C387E48> True
# <keras.layers.core.Activation object at 0x000001BC4C088BE0> True
# <keras.layers.core.Activation object at 0x000001BC4C28E668> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C00BF28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C115B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4C360518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4C088518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4C170FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D411D30> True
# <keras.layers.core.Activation object at 0x000001BC4C088D30> True
# <keras.layers.core.Activation object at 0x000001BC4C1C9EF0> True
# <keras.layers.core.Activation object at 0x000001BC4D459E80> True
# <keras.layers.merge.Concatenate object at 0x000001BC4D438F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D4D1550> True
# <keras.layers.core.Lambda object at 0x000001BC4D521AC8> True
# <keras.layers.core.Activation object at 0x000001BC4D5C9CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D7D0FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D7F2BE0> True
# <keras.layers.core.Activation object at 0x000001BC4D717DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D5F3A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D8194E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D65CAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D8CAE80> True
# <keras.layers.core.Activation object at 0x000001BC4D6ACC88> True
# <keras.layers.core.Activation object at 0x000001BC4D96CA20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D58DDA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D640CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D8FFDA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D5F3908> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D73AAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4D9FEF60> True
# <keras.layers.core.Activation object at 0x000001BC4D5F39B0> True
# <keras.layers.core.Activation object at 0x000001BC4D7A6E10> True
# <keras.layers.core.Activation object at 0x000001BC4DA6ADA0> True
# <keras.layers.merge.Concatenate object at 0x000001BC4DA92F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4D9E2CF8> True
# <keras.layers.core.Lambda object at 0x000001BC4DB49C88> True
# <keras.layers.core.Activation object at 0x000001BC4DB71B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DCE2668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DDE15C0> True
# <keras.layers.core.Activation object at 0x000001BC4DDE1D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DBC59B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DDC4BE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DC25BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DEC5F28> True
# <keras.layers.core.Activation object at 0x000001BC4DBDEE10> True
# <keras.layers.core.Activation object at 0x000001BC4DEA07B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DABA978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DC52470> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4DEA0E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DBC52E8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DCADC50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4DF6CFD0> True
# <keras.layers.core.Activation object at 0x000001BC4DBC5CC0> True
# <keras.layers.core.Activation object at 0x000001BC4DD04CC0> True
# <keras.layers.core.Activation object at 0x000001BC4DFC6C50> True
# <keras.layers.merge.Concatenate object at 0x000001BC4DFA55C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E0376D8> True
# <keras.layers.core.Lambda object at 0x000001BC4E084B70> True
# <keras.layers.core.Activation object at 0x000001BC4E084B38> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E327F28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E34D978> True
# <keras.layers.core.Activation object at 0x000001BC4E26BDA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E159A90> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E36DEF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E1B7AC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E474BE0> True
# <keras.layers.core.Activation object at 0x000001BC4E209C88> True
# <keras.layers.core.Activation object at 0x000001BC4E4C4A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E084710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E19FCF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E456C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E159940> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E290E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E554F98> True
# <keras.layers.core.Activation object at 0x000001BC4E1599E8> True
# <keras.layers.core.Activation object at 0x000001BC4E300DA0> True
# <keras.layers.core.Activation object at 0x000001BC4E5BDDD8> True
# <keras.layers.merge.Concatenate object at 0x000001BC4E5E9F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E534D30> True
# <keras.layers.core.Lambda object at 0x000001BC4E60BCC0> True
# <keras.layers.core.Activation object at 0x000001BC4E69CFD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E838B00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E934630> True
# <keras.layers.core.Activation object at 0x000001BC4E934E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E71D940> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E95BE48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E77CBA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E9F4D30> True
# <keras.layers.core.Activation object at 0x000001BC4E735E48> True
# <keras.layers.core.Activation object at 0x000001BC4E9F49B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E6E14E0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4E7A9470> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EA19CF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E71D240> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4E7FFC50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4EAC3DD8> True
# <keras.layers.core.Activation object at 0x000001BC4E71DC18> True
# <keras.layers.core.Activation object at 0x000001BC4E85BE48> True
# <keras.layers.core.Activation object at 0x000001BC4EB1BC88> True
# <keras.layers.merge.Concatenate object at 0x000001BC4EAF95F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EB8C710> True
# <keras.layers.core.Lambda object at 0x000001BC4EBDCB70> True
# <keras.layers.core.Activation object at 0x000001BC4EC60D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4ECB5B70> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4ED21E10> True
# <keras.layers.core.Activation object at 0x000001BC4ED413C8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4ED04C50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4EDF8F98> True
# <keras.layers.core.Activation object at 0x000001BC4ED04A90> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EBDC710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EDD4550> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4ECB5AC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4EEB5DD8> True
# <keras.layers.core.Activation object at 0x000001BC4ECB5898> True
# <keras.layers.core.Activation object at 0x000001BC4EEF6B70> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001BC4EED8E48> True
# <keras.layers.merge.Concatenate object at 0x000001BC4EF6D208> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EFBBCC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F0DB940> True
# <keras.layers.core.Activation object at 0x000001BC4EFBB5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F0B2CC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F162FD0> True
# <keras.layers.core.Activation object at 0x000001BC4F1B7BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4EF6D438> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F197DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4EFFCE80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F288F60> True
# <keras.layers.core.Activation object at 0x000001BC4F0255F8> True
# <keras.layers.core.Activation object at 0x000001BC4F2F3BE0> True
# <keras.layers.merge.Concatenate object at 0x000001BC4F31AEF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F26B5F8> True
# <keras.layers.core.Lambda object at 0x000001BC4F343B70> True
# <keras.layers.core.Activation object at 0x000001BC4F343E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F44E828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F4699B0> True
# <keras.layers.core.Activation object at 0x000001BC4F4B2B00> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F4DC3C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F535FD0> True
# <keras.layers.core.Activation object at 0x000001BC4F58DC50> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F3F91D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F56D5C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F44E3C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F66DF98> True
# <keras.layers.core.Activation object at 0x000001BC4F44EC50> True
# <keras.layers.core.Activation object at 0x000001BC4F64EE48> True
# <keras.layers.merge.Concatenate object at 0x000001BC4F64E710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F64E9E8> True
# <keras.layers.core.Lambda object at 0x000001BC4F728898> True
# <keras.layers.core.Activation object at 0x000001BC4F7B2C88> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F831978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F870C50> True
# <keras.layers.core.Activation object at 0x000001BC4F851780> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F851630> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F917DA0> True
# <keras.layers.core.Activation object at 0x000001BC4F96FB38> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F728F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC4F94DE10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC4F7F48D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50A21B70> True
# <keras.layers.core.Activation object at 0x000001BC4F7F4F28> True
# <keras.layers.core.Activation object at 0x000001BC50A08A20> True
# <keras.layers.merge.Concatenate object at 0x000001BC50A08828> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50A86D30> True
# <keras.layers.core.Lambda object at 0x000001BC50AD9EB8> True
# <keras.layers.core.Activation object at 0x000001BC50B24358> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50BE2F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50C20AC8> True
# <keras.layers.core.Activation object at 0x000001BC50C7D748> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50C06B38> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50D2A940> True
# <keras.layers.core.Activation object at 0x000001BC50C06DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50AD9B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50D058D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50BB7CC0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50E01C18> True
# <keras.layers.core.Activation object at 0x000001BC50BB7C88> True
# <keras.layers.core.Activation object at 0x000001BC50E55CF8> True
# <keras.layers.merge.Concatenate object at 0x000001BC50DE8CC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50E73E48> True
# <keras.layers.core.Lambda object at 0x000001BC50EC7940> True
# <keras.layers.core.Activation object at 0x000001BC50F4C320> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50FC2DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51003FD0> True
# <keras.layers.core.Activation object at 0x000001BC51003D30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5102B668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC510C6C50> True
# <keras.layers.core.Activation object at 0x000001BC50FE55F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC50EC7D68> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51151F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC50F9CBE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51195D68> True
# <keras.layers.core.Activation object at 0x000001BC50F9CDD8> True
# <keras.layers.core.Activation object at 0x000001BC511EDB38> True
# <keras.layers.merge.Concatenate object at 0x000001BC511CCF28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5125E7B8> True
# <keras.layers.core.Lambda object at 0x000001BC512C7E80> True
# <keras.layers.core.Activation object at 0x000001BC51334DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC513889E8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51411470> True
# <keras.layers.core.Activation object at 0x000001BC51411EF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC513D2C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC514CBF98> True
# <keras.layers.core.Activation object at 0x000001BC513D26A0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC512AAAC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC514A6C50> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51388710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51584E10> True
# <keras.layers.core.Activation object at 0x000001BC51388CC0> True
# <keras.layers.core.Activation object at 0x000001BC515CCEB8> True
# <keras.layers.merge.Concatenate object at 0x000001BC515ABF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51643588> True
# <keras.layers.core.Lambda object at 0x000001BC51693B38> True
# <keras.layers.core.Activation object at 0x000001BC51710DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51767A90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC517CEB00> True
# <keras.layers.core.Activation object at 0x000001BC517CED30> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC517B5550> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC518B1E80> True
# <keras.layers.core.Activation object at 0x000001BC5191EDA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC516D1CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51947F28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51767940> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5196B978> True
# <keras.layers.core.Activation object at 0x000001BC517679E8> True
# <keras.layers.core.Activation object at 0x000001BC5188AE48> True
# <keras.layers.merge.Concatenate object at 0x000001BC51A41EB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5198CD68> True
# <keras.layers.core.Lambda object at 0x000001BC51A90B00> True
# <keras.layers.core.Activation object at 0x000001BC51AE4C50> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51B4C828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51BB0BE0> True
# <keras.layers.core.Activation object at 0x000001BC51C03A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51B987B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51C905F8> True
# <keras.layers.core.Activation object at 0x000001BC51CFCB70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51AE4358> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51D29E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51B4C6D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51D9DBA8> True
# <keras.layers.core.Activation object at 0x000001BC51B4CD68> True
# <keras.layers.core.Activation object at 0x000001BC51D56DA0> True
# <keras.layers.merge.Concatenate object at 0x000001BC51DC9470> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51D7C860> True
# <keras.layers.core.Lambda object at 0x000001BC51E78E80> True
# <keras.layers.core.Activation object at 0x000001BC51E58978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51F386A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51F5EDD8> True
# <keras.layers.core.Activation object at 0x000001BC51F9AE48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51F786D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC520E2E10> True
# <keras.layers.core.Activation object at 0x000001BC520E2A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC51EC59E8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5210CCF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC51F38550> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52135D30> True
# <keras.layers.core.Activation object at 0x000001BC51F38BE0> True
# <keras.layers.core.Activation object at 0x000001BC521359B0> True
# <keras.layers.merge.Concatenate object at 0x000001BC5215CCF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC521BFA20> True
# <keras.layers.core.Lambda object at 0x000001BC5225BC88> True
# <keras.layers.core.Activation object at 0x000001BC522E9828> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5231FA58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52340C88> True
# <keras.layers.core.Activation object at 0x000001BC5237EE80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5240EF60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5245FAC8> True
# <keras.layers.core.Activation object at 0x000001BC524C3978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC522CC710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52446748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5231F518> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5253CF98> True
# <keras.layers.core.Activation object at 0x000001BC5231FE80> True
# <keras.layers.core.Activation object at 0x000001BC52446908> True
# <keras.layers.merge.Concatenate object at 0x000001BC5251A550> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5251ABE0> True
# <keras.layers.core.Lambda object at 0x000001BC5263DE10> True
# <keras.layers.core.Activation object at 0x000001BC526CE630> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC527028D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5271EFD0> True
# <keras.layers.core.Activation object at 0x000001BC52702D68> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5273DAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC527EEE80> True
# <keras.layers.core.Activation object at 0x000001BC52895A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC526B5240> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52827DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52702390> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52925F60> True
# <keras.layers.core.Activation object at 0x000001BC52702DD8> True
# <keras.layers.core.Activation object at 0x000001BC52990DA0> True
# <keras.layers.merge.Concatenate object at 0x000001BC529B7F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5290ACF8> True
# <keras.layers.core.Lambda object at 0x000001BC529FFCF8> True
# <keras.layers.core.Activation object at 0x000001BC52A6EF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52AEE668> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52B4FB70> True
# <keras.layers.core.Activation object at 0x000001BC52B06E10> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52B797F0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52BD2780> True
# <keras.layers.core.Activation object at 0x000001BC52C2CCC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52AB04A8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52C08630> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52AEE208> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52D075C0> True
# <keras.layers.core.Activation object at 0x000001BC52AEECC0> True
# <keras.layers.core.Activation object at 0x000001BC52C9B748> True
# <keras.layers.merge.Concatenate object at 0x000001BC52CEC710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52CECB70> True
# <keras.layers.core.Lambda object at 0x000001BC52DC57F0> True
# <keras.layers.core.Activation object at 0x000001BC52E52AC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52ECC6A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52F0AF28> True
# <keras.layers.core.Activation object at 0x000001BC52EECEB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52EEC6A0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC53F83FD0> True
# <keras.layers.core.Activation object at 0x000001BC53FDAE48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC52DC5F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC53FB9FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC52E93F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC540BEF60> True
# <keras.layers.core.Activation object at 0x000001BC52E93EF0> True
# <keras.layers.core.Activation object at 0x000001BC54054278> True
# <keras.layers.merge.Concatenate object at 0x000001BC540A3390> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC540A3630> True
# <keras.layers.core.Lambda object at 0x000001BC54174780> True
# <keras.layers.core.Activation object at 0x000001BC54234470> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54280D30> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC542BD6A0> True
# <keras.layers.core.Activation object at 0x000001BC54280940> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5431C3C8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5437BC18> True
# <keras.layers.core.Activation object at 0x000001BC543C2FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54174E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5439D5F8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54247FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC544F34A8> True
# <keras.layers.core.Activation object at 0x000001BC54247E80> True
# <keras.layers.core.Activation object at 0x000001BC5449DD30> True
# <keras.layers.merge.Concatenate object at 0x000001BC54502A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54485550> True
# <keras.layers.core.Lambda object at 0x000001BC54565978> True
# <keras.layers.core.Activation object at 0x000001BC545A6160> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54663E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC546A1C18> True
# <keras.layers.core.Activation object at 0x000001BC546FC320> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54686F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC547AEB38> True
# <keras.layers.core.Activation object at 0x000001BC5475DDA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54565DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC547D71D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5463BC18> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54832E10> True
# <keras.layers.core.Activation object at 0x000001BC5463BE80> True
# <keras.layers.core.Activation object at 0x000001BC547887B8> True
# <keras.layers.merge.Concatenate object at 0x000001BC548FA828> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC548FAE10> True
# <keras.layers.core.Lambda object at 0x000001BC549486D8> True
# <keras.layers.core.Activation object at 0x000001BC549D0D68> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54A45C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54A86FD0> True
# <keras.layers.core.Activation object at 0x000001BC54A6AE80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54A6AB38> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54B6CC88> True
# <keras.layers.core.Activation object at 0x000001BC54B47908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54948B38> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54B47A20> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54A21E10> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54C16908> True
# <keras.layers.core.Activation object at 0x000001BC54A21CF8> True
# <keras.layers.core.Activation object at 0x000001BC54C6BF28> True
# <keras.layers.merge.Concatenate object at 0x000001BC54C4A588> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54CE26A0> True
# <keras.layers.core.Lambda object at 0x000001BC54D31BA8> True
# <keras.layers.core.Activation object at 0x000001BC54DB2BE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54E06B00> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54E2B710> True
# <keras.layers.core.Activation object at 0x000001BC54EC1C50> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54D4A0B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54F4D4E0> True
# <keras.layers.core.Activation object at 0x000001BC54E95710> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54D6FD68> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC54F249B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC54E069B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5500ADA0> True
# <keras.layers.core.Activation object at 0x000001BC54E06A58> True
# <keras.layers.core.Activation object at 0x000001BC54FE45F8> True
# <keras.layers.merge.Concatenate object at 0x000001BC550E0F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5502BDA0> True
# <keras.layers.core.Lambda object at 0x000001BC55113080> True
# <keras.layers.core.Activation object at 0x000001BC55113940> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC551EA8D0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55211BE0> True
# <keras.layers.core.Activation object at 0x000001BC5524DC18> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC552B3978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55330F60> True
# <keras.layers.core.Activation object at 0x000001BC5539BBE0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55113A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC553C6EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC551EA780> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5543DC18> True
# <keras.layers.core.Activation object at 0x000001BC551EA860> True
# <keras.layers.core.Activation object at 0x000001BC553F2E80> True
# <keras.layers.merge.Concatenate object at 0x000001BC554664E0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55413898> True
# <keras.layers.core.Lambda object at 0x000001BC55562630> True
# <keras.layers.core.Activation object at 0x000001BC55562A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC555D7710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC555F8C88> True
# <keras.layers.core.Activation object at 0x000001BC5563AB70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55617DA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55719F98> True
# <keras.layers.core.Activation object at 0x000001BC556F6E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC554F49E8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC556F6710> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC555D75C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC557D4C18> True
# <keras.layers.core.Activation object at 0x000001BC555D7C50> True
# <keras.layers.core.Activation object at 0x000001BC5577ED30> True
# <keras.layers.merge.Concatenate object at 0x000001BC557FCA58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC557FC828> True
# <keras.layers.core.Lambda object at 0x000001BC558FBE48> True
# <keras.layers.core.Activation object at 0x000001BC55985898> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC559BBAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC559DBC18> True
# <keras.layers.core.Activation object at 0x000001BC55A1AEF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55AABFD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55AFDB70> True
# <keras.layers.core.Activation object at 0x000001BC55AE2A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55969780> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55AE2828> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC559BB588> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55BDCE48> True
# <keras.layers.core.Activation object at 0x000001BC559BBF98> True
# <keras.layers.core.Activation object at 0x000001BC55B60D30> True
# <keras.layers.merge.Concatenate object at 0x000001BC55BB6518> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55BB6EB8> True
# <keras.layers.core.Lambda object at 0x000001BC55CDBE10> True
# <keras.layers.core.Activation object at 0x000001BC55CDBE80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC56052FD0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56075BE0> True
# <keras.layers.core.Activation object at 0x000001BC55F96DA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55D6F6A0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55E8CF60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC56097A90> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55DA0400> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55EDDAC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56145E80> True
# <keras.layers.core.Activation object at 0x000001BC55DA0F98> True
# <keras.layers.core.Activation object at 0x000001BC55F2EC88> True
# <keras.layers.core.Activation object at 0x000001BC561E7A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55DA0940> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC55EC2EB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5617CDA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55DC0C88> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC55FB8AC8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56275F60> True
# <keras.layers.core.Activation object at 0x000001BC55DA09E8> True
# <keras.layers.core.Activation object at 0x000001BC56026E10> True
# <keras.layers.core.Activation object at 0x000001BC562E0DA0> True
# <keras.layers.pooling.MaxPooling2D object at 0x000001BC56308F60> True
# <keras.layers.merge.Concatenate object at 0x000001BC56257908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC563A5E80> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56450F28> True
# <keras.layers.core.Activation object at 0x000001BC56435F98> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC56435F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56537F28> True
# <keras.layers.core.Activation object at 0x000001BC5650E438> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5632DAC8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5650EE48> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC56375F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC565E0FD0> True
# <keras.layers.core.Activation object at 0x000001BC563A5550> True
# <keras.layers.core.Activation object at 0x000001BC56637C50> True
# <keras.layers.merge.Concatenate object at 0x000001BC566175C0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC566A76D8> True
# <keras.layers.core.Lambda object at 0x000001BC566F5B38> True
# <keras.layers.core.Activation object at 0x000001BC566F56D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC577A4B38> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5780ADD8> True
# <keras.layers.core.Activation object at 0x000001BC5782B390> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC577F0BE0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC578E94A8> True
# <keras.layers.core.Activation object at 0x000001BC577F0A58> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC566F5B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC578C2EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC577A49E8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC579A4DA0> True
# <keras.layers.core.Activation object at 0x000001BC577A4A90> True
# <keras.layers.core.Activation object at 0x000001BC579E8B38> True
# <keras.layers.merge.Concatenate object at 0x000001BC57A79FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC579C7E10> True
# <keras.layers.core.Lambda object at 0x000001BC57AB0550> True
# <keras.layers.core.Activation object at 0x000001BC57AB0A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57B81780> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57C3E4A8> True
# <keras.layers.core.Activation object at 0x000001BC57C4C9B0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57BCEA58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57CCCC18> True
# <keras.layers.core.Activation object at 0x000001BC57D37D68> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57AB0DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57D5EF28> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57B819B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57DD4940> True
# <keras.layers.core.Activation object at 0x000001BC57B81AC8> True
# <keras.layers.core.Activation object at 0x000001BC57CAFB70> True
# <keras.layers.merge.Concatenate object at 0x000001BC57DAECC0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57DAE8D0> True
# <keras.layers.core.Lambda object at 0x000001BC57EFF198> True
# <keras.layers.core.Activation object at 0x000001BC57EFFCF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57F73748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57F92DA0> True
# <keras.layers.core.Activation object at 0x000001BC5801F978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57FB36D8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC580B1FD0> True
# <keras.layers.core.Activation object at 0x000001BC58096E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57E91A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58096748> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC57F735F8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5816FC50> True
# <keras.layers.core.Activation object at 0x000001BC57F73C88> True
# <keras.layers.core.Activation object at 0x000001BC58117D68> True
# <keras.layers.merge.Concatenate object at 0x000001BC581FBF98> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58196860> True
# <keras.layers.core.Lambda object at 0x000001BC58296B38> True
# <keras.layers.core.Activation object at 0x000001BC583208D0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58357978> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58377F98> True
# <keras.layers.core.Activation object at 0x000001BC583B5F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58446F98> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58496BA8> True
# <keras.layers.core.Activation object at 0x000001BC58394F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC583057B8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5847DA58> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC583575C0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58577F98> True
# <keras.layers.core.Activation object at 0x000001BC58357B00> True
# <keras.layers.core.Activation object at 0x000001BC584FAEB8> True
# <keras.layers.merge.Concatenate object at 0x000001BC58553C88> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58553C50> True
# <keras.layers.core.Lambda object at 0x000001BC58678E48> True
# <keras.layers.core.Activation object at 0x000001BC58678EB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58737940> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58759E10> True
# <keras.layers.core.Activation object at 0x000001BC58737978> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58778438> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58829F98> True
# <keras.layers.core.Activation object at 0x000001BC5887AA90> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC587066D8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC57ACB080> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58737438> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5895A828> True
# <keras.layers.core.Activation object at 0x000001BC58737E80> True
# <keras.layers.core.Activation object at 0x000001BC589C7DA0> True
# <keras.layers.merge.Concatenate object at 0x000001BC589F1F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5893EC88> True
# <keras.layers.core.Lambda object at 0x000001BC58A61A90> True
# <keras.layers.core.Activation object at 0x000001BC58A61A20> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58B22D68> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58B83C18> True
# <keras.layers.core.Activation object at 0x000001BC58B3AEB8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58BAF4E0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58D5DE10> True
# <keras.layers.core.Activation object at 0x000001BC58DB3B70> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58AEA5F8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58D91278> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58B222B0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC58E8A5F8> True
# <keras.layers.core.Activation object at 0x000001BC58B22898> True
# <keras.layers.core.Activation object at 0x000001BC58EF6BA8> True
# <keras.layers.merge.Concatenate object at 0x000001BC58F24E80> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58E6BC50> True
# <keras.layers.core.Lambda object at 0x000001BC58F4EB00> True
# <keras.layers.core.Activation object at 0x000001BC58F4EE10> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC590547B8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59077D30> True
# <keras.layers.core.Activation object at 0x000001BC59054A90> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC590E2B70> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5913EFD0> True
# <keras.layers.core.Activation object at 0x000001BC59195EF0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC58FD9F28> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59174BA8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59054908> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC592DAE10> True
# <keras.layers.core.Activation object at 0x000001BC59054D30> True
# <keras.layers.core.Activation object at 0x000001BC592DAA20> True
# <keras.layers.merge.Concatenate object at 0x000001BC59305CF8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5925BC50> True
# <keras.layers.core.Lambda object at 0x000001BC59331E10> True
# <keras.layers.core.Activation object at 0x000001BC593EE358> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59438CF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59476E48> True
# <keras.layers.core.Activation object at 0x000001BC59438DD8> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59459CF8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5952FD30> True
# <keras.layers.core.Activation object at 0x000001BC59459C50> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59331FD0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59608F60> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC593FDDD8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59659AC8> True
# <keras.layers.core.Activation object at 0x000001BC593FDEB8> True
# <keras.layers.core.Activation object at 0x000001BC596BC978> True
# <keras.layers.merge.Concatenate object at 0x000001BC59640908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59640748> True
# <keras.layers.core.Lambda object at 0x000001BC59735208> True
# <keras.layers.core.Activation object at 0x000001BC59735F60> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5981AEB8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC5985CAC8> True
# <keras.layers.core.Activation object at 0x000001BC598B2400> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5983DDA0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59964BE0> True
# <keras.layers.core.Activation object at 0x000001BC59917E48> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC5975DC18> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC599914A8> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC597F2EF0> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC599E9E80> True
# <keras.layers.core.Activation object at 0x000001BC597F2FD0> True
# <keras.layers.core.Activation object at 0x000001BC59D2DA20> True
# <keras.layers.merge.Concatenate object at 0x000001BC59A1FDA0> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59D56AC8> True
# <keras.layers.core.Lambda object at 0x000001BC59DA0908> True
# <keras.layers.convolutional.Conv2D object at 0x000001BC59E28630> True
# <keras.layers.normalization.BatchNormalization object at 0x000001BC59E75CC0> True
# <keras.layers.core.Activation object at 0x000001BC59E75DA0> True

# %%
#   first: train only the top layers (which were randomly initialized)
#   i.e. freeze all convolutional  layers
for layer in base_model.layers:
    layer.trainable = True

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# %%
y_train_one_hot = tf.one_hot( y_train, n_classes ).eval()

# %%
data_train_gen = data_generator(sess, X_train, y_train_one_hot )

# %%
print( data_train_gen )
# Out:
# <function data_generator.<locals>.generator at 0x000001BC59E49B70>

# %%
# train the model on the new data for a "few" epochs
model.fit_generator(data_train_gen(), n_training/batch_size, verbose=1)
# Out:
# Epoch 1/1
# 782/781 [==============================] - 531s 680ms/step - loss: 1.0241

# %% [markdown]
# ## Validation

# %%
#resize images
images_resized = sess.run(tf_resize_op, {batch_of_images_placeholder: X_test})
images = preprocess_input(images_resized)

# %%
print( images.shape )
# Out:
# (10000, 224, 224, 3)

# %%
result = base_model.predict(images, verbose=2)

# %%
y_pred = [ np.argmax( result[i] ) for i in range(n_testing) ]

# %%
np.sum( y_pred == y_test ) / n_testing
# Out:
# 0.0

# %%
# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.001, momentum=0.9), loss='categorical_crossentropy')

# %%
model.fit_generator(data_train_gen(), n_training/batch_size, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 782/781 [==============================] - 517s 661ms/step - loss: 0.3835
# Epoch 2/10
# 782/781 [==============================] - 514s 657ms/step - loss: 0.3141
# Epoch 3/10
# 782/781 [==============================] - 501s 640ms/step - loss: 0.2883
# Epoch 4/10
# 782/781 [==============================] - 500s 639ms/step - loss: 0.2708
# Epoch 5/10
# 782/781 [==============================] - 508s 650ms/step - loss: 0.2574
# Epoch 6/10
# 782/781 [==============================] - 505s 645ms/step - loss: 0.2465
# Epoch 7/10
# 782/781 [==============================] - 502s 642ms/step - loss: 0.2368
# Epoch 8/10
# 782/781 [==============================] - 502s 643ms/step - loss: 0.2283
# Epoch 9/10
# 782/781 [==============================] - 503s 643ms/step - loss: 0.2203
# Epoch 10/10
# 782/781 [==============================] - 501s 641ms/step - loss: 0.2129

# %%
result = model.predict(images, verbose=1)
y_pred = [ np.argmax( result[i] ) for i in range(n_testing) ]
np.sum( y_pred == y_test ) / n_testing
# Out:
# 10000/10000 [==============================] - 43s 4ms/step
# 0.886
